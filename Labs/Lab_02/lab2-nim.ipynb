# %% [markdown]
# Copyright **`(c)`** 2022 Giovanni Squillero `<squillero@polito.it>`
# [`https://github.com/squillero/computational-intelligence`](https://github.com/squillero/computational-intelligence)
# Free for personal or classroom use; see [`LICENSE.md`](https://github.com/squillero/computational-intelligence/blob/master/LICENSE.md) for details.

# %% [markdown]
# # Lab 3: ES
#
# ## Task
#
# Write agents able to play [*Nim*](https://en.wikipedia.org/wiki/Nim), with an arbitrary number of rows and an upper bound $k$ on the number of objects that can be removed in a turn (a.k.a., *subtraction game*).
#
# The goal of the game is to **avoid** taking the last object.
#
# * Task2.1: An agent using fixed rules based on *nim-sum* (i.e., an *expert system*)
# * Task2.2: An agent using evolved rules using ES
#
# ## Instructions
#
# * Create the directory `lab2` inside your personal course repository for the course
# * Put a `README.md` and your solution (all the files, code and auxiliary data if needed)
#
# ## Notes
#
# * Working in group is not only allowed, but recommended (see: [Ubuntu](https://en.wikipedia.org/wiki/Ubuntu_philosophy) and [Cooperative Learning](https://files.eric.ed.gov/fulltext/EJ1096789.pdf)). Collaborations must be explicitly declared in the `README.md`.
# * [Yanking](https://www.emacswiki.org/emacs/KillingAndYanking) from the internet is allowed, but sources must be explicitly declared in the `README.md`.

# %%
import logging
from pprint import pprint, pformat
from collections import namedtuple
import random
from copy import deepcopy, copy
from tqdm import tqdm
from matplotlib import pyplot as plt
from dataclasses import dataclass
import numpy as np

# %% [markdown]
# ## The *Nim* and *Nimply* classes

# %%
Nimply = namedtuple("Nimply", "row, num_objects")
N_ROWS = 5
GAME_DIMENSION = N_ROWS
ELEMENT_PER_ROW = 2*N_ROWS - 1
POPULATION_SIZE = 5             # μ
OFFSPRING_SIZE = 20             # λ
MUTATION_STEP = 2               # σ
NUM_GENERATIONS = 1000

# %%
class Nim:
    def __init__(self, num_rows: int, k: int = None) -> None:
        self._rows = [i * 2 + 1 for i in range(num_rows)]
        self._k = k

    def __bool__(self):
        return sum(self._rows) > 0

    def __str__(self):
        return "<" + " ".join(str(_) for _ in self._rows) + ">"

    @property
    def rows(self) -> tuple:
        return tuple(self._rows)

    def nimming(self, ply: Nimply) -> None:
        row, num_objects = ply
        assert self._rows[row] >= num_objects
        assert self._k is None or num_objects <= self._k
        self._rows[row] -= num_objects

# %% [markdown]
# ## Sample (and silly) startegies

# %%
def pure_random(state: Nim) -> Nimply:
    """A completely random move"""
    row = random.choice([r for r, c in enumerate(state.rows) if c > 0])
    num_objects = random.randint(1, state.rows[row])
    return Nimply(row, num_objects)

# %%
def gabriele(state: Nim) -> Nimply:
    """Pick always the maximum possible number of the lowest row"""
    possible_moves = [(r, o) for r, c in enumerate(state.rows) for o in range(1, c + 1)]
    return Nimply(*max(possible_moves, key=lambda m: (-m[0], m[1])))

# %%
def adaptive(state: Nim) -> Nimply:
    """A strategy that can adapt its parameters"""
    genome = {"love_small": 0.5}

# %%
import numpy as np


def nim_sum(state: Nim) -> int:
    tmp = np.array([tuple(int(x) for x in f"{c:032b}") for c in state.rows])
    xor = tmp.sum(axis=0) % 2
    return int("".join(str(_) for _ in xor), base=2)


def analize(raw: Nim) -> dict:
    cooked = dict()
    cooked["possible_moves"] = dict()
    for ply in (Nimply(r, o) for r, c in enumerate(raw.rows) for o in range(1, c + 1)):
        tmp = deepcopy(raw)
        tmp.nimming(ply)
        cooked["possible_moves"][ply] = nim_sum(tmp)
    return cooked


def optimal(state: Nim) -> Nimply:
    analysis = analize(state)
    logging.debug(f"analysis:\n{pformat(analysis)}")
    spicy_moves = [ply for ply, ns in analysis["possible_moves"].items() if ns != 0]
    if not spicy_moves:
        spicy_moves = list(analysis["possible_moves"].keys())
    ply = random.choice(spicy_moves)
    return ply

# %% [markdown]
# ## Oversimplified match

# %%
logging.getLogger().setLevel(logging.INFO)

strategy = (optimal, pure_random)

nim = Nim(5)
logging.info(f"init : {nim}")
player = 0
while nim:
    ply = strategy[player](nim)
    logging.info(f"ply: player {player} plays {ply}")
    nim.nimming(ply)
    logging.info(f"status: {nim}")
    player = 1 - player
logging.info(f"status: Player {player} won!")

# %% [markdown]
# ## ES (1 + λ)

# %%
@dataclass
class Individual:
    genotype: list[list[float], list[list[float]]]
    fitness: float

# %%
def player_move(ind: Individual, state: Nim) -> Nimply:
    agent = deepcopy(ind)
    rows = [i for i in range(N_ROWS)]
    element = [i for i in range(ELEMENT_PER_ROW)]

    for r, n in enumerate(state.rows):
        if n == 0:
            agent.genotype[0][r] = 0.0
        
        for j in range(ELEMENT_PER_ROW):
            if j >= n:
                agent.genotype[1][r][j] = 0.0
    
    agent.genotype[0] = agent.genotype[0]/(np.sum(agent.genotype[0]) + 1e-9)
    agent.genotype[1] = agent.genotype[1]/(np.reshape(np.sum(agent.genotype[1], axis=1), (N_ROWS, 1)) + 1e-9)
    
    row = random.choices(rows, weights=agent.genotype[0])[0]
    elem = random.choices(element, weights=np.squeeze(agent.genotype[1][row, :]))[0]
    return Nimply(row, elem+1)

# %%
def evolve_Individual(ind: Individual) -> list:
    new_population = [deepcopy(ind)]
    for _ in range(OFFSPRING_SIZE):
        offspring = deepcopy(ind)
        mutation_gene_1 = np.random.normal(loc=0, scale=2, size=(N_ROWS))
        new_gene_1 = np.abs(offspring.genotype[0] + mutation_gene_1)
        tot = np.sum(new_gene_1)
        offspring.genotype[0]=np.array(new_gene_1/tot)
        # - - - - - - #
        mutation_gene_2 = np.random.normal(loc=0, scale=2, size=(N_ROWS, ELEMENT_PER_ROW))
        for r in range(1, N_ROWS+1):
            for i in range(ELEMENT_PER_ROW):
                if i>=2*r-1:
                    mutation_gene_2[r-1, i]=0
        new_gene_2 = np.abs(mutation_gene_2 + ind.genotype[1])
        tot = np.reshape(np.sum(new_gene_2, axis=1), (N_ROWS, 1))
        offspring.genotype[1]=np.array(new_gene_2/tot)

        new_population.append(offspring)

    return new_population

# %%
def Evaluation(players) -> float:
    win = 0
    
    for _ in range(100):
        nim = Nim(GAME_DIMENSION)
        # logging.info(f"init : {nim}")
        player = random.choice([0, 1])
        while nim:
            if player == 0:
                ply = player_move(players[0], nim)
                # logging.info(f"ply: player agent plays {ply}")

            if player == 1:
                ply = players[player](nim)
                # logging.info(f"ply: opponent plays {ply}")

            nim.nimming(ply)
            # logging.info(f"status: {nim}")
            player = 1 - player
        # logging.info(f"status: { 'Agent'if player==0 else 'Opponent'} won!")
        if player == 0 : win += 1
        
    return win/100

# %%
first_player = Individual(
    genotype=[
        np.array([1/N_ROWS for _ in range(N_ROWS)]), 
        np.array([[1/(2*r-1) if i<2*r-1 else 0 for i in range(ELEMENT_PER_ROW) ] for r in range(1, N_ROWS+1)])
        ],
    fitness = 0.0)

# %%
logging.getLogger().setLevel(logging.INFO)
solution = first_player
history = list()
best_agent = deepcopy(solution)
# history.append(solution)

opponent = pure_random

for n in tqdm(range(1_000 // OFFSPRING_SIZE)):
    evals = []
    # offspring <- select λ random points mutating the current solution
    offsprings = evolve_Individual(solution)
    # evaluate and select best
    for player in offsprings:
        player.fitness = Evaluation((player, opponent))
        # logging.info(f"Agent {n} won {player.fitness*100} over 100 matches")
        evals.append(player.fitness)
    
    # max(population, key=lambda i:i.fitness, reverse=True)
    solution = offsprings[np.argmax(evals)]
    logging.info(f"\nBest Agent of {n+1}° generation won {round(solution.fitness*100, 2)} over 100 matches\n")
    if best_agent.fitness < solution.fitness:
        best_agent = deepcopy(solution)
    history.append(best_agent.fitness)
    logging.info(f"\nBest Agent util now have won {round(best_agent.fitness*100, 2)} over 100 matches\n")


logging.info(f"\nBest solution: {best_agent.fitness}\nRows choice: {best_agent.genotype[0]}\nElement choice: {best_agent.genotype[1]}")

history = np.array(history)
generations = list(range(1, 50 + 1))
plt.plot(generations, history, marker='o', linestyle='-', color='r')
plt.title('Fitness Over Generations')
plt.xlabel('Generation')
plt.ylabel('Fitness')
plt.grid(True)
plt.show()

# %% [markdown]
# ## ES (μ + λ)

# %%
first_population = []

for m in range(5):
    gene_1 = np.array([random.random() for _ in range(N_ROWS)])
    gene_2 = np.array([[random.random() if i<2*r-1 else 0 for i in range(ELEMENT_PER_ROW) ] for r in range(1, N_ROWS+1)])

    first_population.append(Individual(
        genotype=[
            gene_1/np.sum(gene_1), 
            gene_2/np.reshape(np.sum(gene_2, axis=1), (N_ROWS, 1))
            ],
        fitness = 0.0))

# %%
def mutate_Individual(ind: Individual) -> list:
    offspring = deepcopy(ind)
    mutation_gene_1 = np.random.normal(loc=0, scale=2, size=(N_ROWS))
    new_gene_1 = np.abs(offspring.genotype[0] + mutation_gene_1)
    tot = np.sum(new_gene_1)
    offspring.genotype[0]=np.array(new_gene_1/tot)
    # - - - - - - #
    mutation_gene_2 = np.random.normal(loc=0, scale=2, size=(N_ROWS, ELEMENT_PER_ROW))
    for r in range(1, N_ROWS+1):
        for i in range(ELEMENT_PER_ROW):
            if i>=2*r-1:
                mutation_gene_2[r-1, i]=0
    new_gene_2 = np.abs(mutation_gene_2 + ind.genotype[1])
    tot = np.reshape(np.sum(new_gene_2, axis=1), (N_ROWS, 1))
    offspring.genotype[1]=np.array(new_gene_2/tot)

    return offspring

# %%
logging.getLogger().setLevel(logging.INFO)

current_population = first_population
history = list()
best_so_far = deepcopy(solution)

opponent = pure_random

for n in tqdm(range(50)):
    offsprings = []
    
    for _ in range(OFFSPRING_SIZE):
        offsprings.append(mutate_Individual(current_population[random.choice(range(POPULATION_SIZE))]))

    for player in offsprings:
        player.fitness = Evaluation((player, opponent))
    
    current_population.extend(offsprings)
    current_population.sort(key=lambda i:i.fitness, reverse=True)       # ORDERING FROM BEST TO WORSE
    current_population = current_population[:POPULATION_SIZE]       # SURVIVAL SELECTION    solution = offsprings[np.argmax(evals)]
    
    logging.info(f"\nBest Agent of {n+1}° generation won {round(current_population[0].fitness*100, 2)} over 100 matches\n")
    history.append(current_population[0].fitness)

best_agent = copy(current_population[0])
logging.info(f"\nBest solution: {best_agent.fitness}\nRows choice: {best_agent.genotype[0]}\nElement choice: {best_agent.genotype[1]}")

history = np.array(history)
generations = list(range(1, 50 + 1))
plt.plot(generations, history, marker='o', linestyle='-', color='r')
plt.title('Fitness Over Generations')
plt.xlabel('Generation')
plt.ylabel('Fitness')
plt.grid(True)
plt.show()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]INFO:root:
# Best Agent of 1° generation won 58.0 over 100 matches
#
#   0%|          | 1/1000 [00:05<1:31:14,  5.48s/it]INFO:root:
# Best Agent of 2° generation won 59.0 over 100 matches
#
#   0%|          | 2/1000 [00:09<1:21:29,  4.90s/it]INFO:root:
# Best Agent of 3° generation won 63.0 over 100 matches
#
#   0%|          | 3/1000 [00:14<1:20:58,  4.87s/it]INFO:root:
# Best Agent of 4° generation won 63.0 over 100 matches
#
#   0%|          | 4/1000 [00:18<1:16:14,  4.59s/it]INFO:root:
# Best Agent of 5° generation won 63.0 over 100 matches
#
#   0%|          | 5/1000 [00:23<1:13:26,  4.43s/it]INFO:root:
# Best Agent of 6° generation won 63.0 over 100 matches
#
#   1%|          | 6/1000 [00:27<1:11:10,  4.30s/it]INFO:root:
# Best Agent of 7° generation won 63.0 over 100 matches
#
#   1%|          | 7/1000 [00:32<1:14:41,  4.51s/it]INFO:root:
# Best Agent of 8° generation won 63.0 over 100 matches
#
#   1%|          | 8/1000 [00:36<1:13:35,  4.45s/it]INFO:root:
# Best Agent of 9° generation won 63.0 over 100 matches
#
#   1%|          | 9/1000 [00:40<1:12:46,  4.41s/it]INFO:root:
# Best Agent of 10° generation won 63.0 over 100 matches
#
#   1%|          | 10/1000 [00:45<1:12:46,  4.41s/it]INFO:root:
# Best Agent of 11° generation won 64.0 over 100 matches
#
#   1%|          | 11/1000 [00:50<1:15:40,  4.59s/it]INFO:root:
# Best Agent of 12° generation won 64.0 over 100 matches
#
#   1%|          | 12/1000 [00:54<1:13:38,  4.47s/it]INFO:root:
# Best Agent of 13° generation won 64.0 over 100 matches
#
#   1%|▏         | 13/1000 [00:58<1:11:54,  4.37s/it]INFO:root:
# Best Agent of 14° generation won 64.0 over 100 matches
#
#   1%|▏         | 14/1000 [01:02<1:10:41,  4.30s/it]INFO:root:
# Best Agent of 15° generation won 64.0 over 100 matches
#
#   2%|▏         | 15/1000 [01:06<1:09:02,  4.21s/it]INFO:root:
# Best Agent of 16° generation won 64.0 over 100 matches
#
#   2%|▏         | 16/1000 [01:10<1:07:41,  4.13s/it]INFO:root:
# Best Agent of 17° generation won 64.0 over 100 matches
#
#   2%|▏         | 17/1000 [01:14<1:07:19,  4.11s/it]INFO:root:
# Best Agent of 18° generation won 64.0 over 100 matches
#
#   2%|▏         | 18/1000 [01:18<1:06:16,  4.05s/it]INFO:root:
# Best Agent of 19° generation won 64.0 over 100 matches
#
#   2%|▏         | 19/1000 [01:22<1:05:53,  4.03s/it]INFO:root:
# Best Agent of 20° generation won 64.0 over 100 matches
#
#   2%|▏         | 20/1000 [01:26<1:05:20,  4.00s/it]INFO:root:
# Best Agent of 21° generation won 64.0 over 100 matches
#
#   2%|▏         | 21/1000 [01:30<1:05:06,  3.99s/it]INFO:root:
# Best Agent of 22° generation won 65.0 over 100 matches
#
#   2%|▏         | 22/1000 [01:34<1:04:50,  3.98s/it]INFO:root:
# Best Agent of 23° generation won 66.0 over 100 matches
#
#   2%|▏         | 23/1000 [01:38<1:04:56,  3.99s/it]INFO:root:
# Best Agent of 24° generation won 66.0 over 100 matches
#
#   2%|▏         | 24/1000 [01:42<1:05:13,  4.01s/it]INFO:root:
# Best Agent of 25° generation won 66.0 over 100 matches
#
#   2%|▎         | 25/1000 [01:46<1:04:58,  4.00s/it]INFO:root:
# Best Agent of 26° generation won 66.0 over 100 matches
#
#   3%|▎         | 26/1000 [01:50<1:05:00,  4.00s/it]INFO:root:
# Best Agent of 27° generation won 66.0 over 100 matches
#
#   3%|▎         | 27/1000 [01:54<1:03:45,  3.93s/it]INFO:root:
# Best Agent of 28° generation won 66.0 over 100 matches
#
#   3%|▎         | 28/1000 [01:58<1:04:32,  3.98s/it]INFO:root:
# Best Agent of 29° generation won 66.0 over 100 matches
#
#   3%|▎         | 29/1000 [02:02<1:03:56,  3.95s/it]INFO:root:
# Best Agent of 30° generation won 66.0 over 100 matches
#
#   3%|▎         | 30/1000 [02:06<1:03:21,  3.92s/it]INFO:root:
# Best Agent of 31° generation won 66.0 over 100 matches
#
#   3%|▎         | 31/1000 [02:09<1:02:47,  3.89s/it]INFO:root:
# Best Agent of 32° generation won 71.0 over 100 matches
#
#   3%|▎         | 32/1000 [02:13<1:03:00,  3.91s/it]INFO:root:
# Best Agent of 33° generation won 71.0 over 100 matches
#
#   3%|▎         | 33/1000 [02:17<1:02:22,  3.87s/it]INFO:root:
# Best Agent of 34° generation won 71.0 over 100 matches
#
#   3%|▎         | 34/1000 [02:21<1:02:10,  3.86s/it]INFO:root:
# Best Agent of 35° generation won 71.0 over 100 matches
#
#   4%|▎         | 35/1000 [02:25<1:02:31,  3.89s/it]INFO:root:
# Best Agent of 36° generation won 71.0 over 100 matches
#
#   4%|▎         | 36/1000 [02:29<1:02:18,  3.88s/it]INFO:root:
# Best Agent of 37° generation won 71.0 over 100 matches
#
#   4%|▎         | 37/1000 [02:33<1:02:33,  3.90s/it]INFO:root:
# Best Agent of 38° generation won 71.0 over 100 matches
#
#   4%|▍         | 38/1000 [02:36<1:01:43,  3.85s/it]INFO:root:
# Best Agent of 39° generation won 71.0 over 100 matches
#
#   4%|▍         | 39/1000 [02:40<1:01:29,  3.84s/it]INFO:root:
# Best Agent of 40° generation won 71.0 over 100 matches
#
#   4%|▍         | 40/1000 [02:44<1:01:43,  3.86s/it]INFO:root:
# Best Agent of 41° generation won 71.0 over 100 matches
#
#   4%|▍         | 41/1000 [02:48<1:02:16,  3.90s/it]INFO:root:
# Best Agent of 42° generation won 71.0 over 100 matches
#
#   4%|▍         | 42/1000 [02:52<1:02:07,  3.89s/it]INFO:root:
# Best Agent of 43° generation won 71.0 over 100 matches
#
#   4%|▍         | 43/1000 [02:56<1:01:35,  3.86s/it]INFO:root:
# Best Agent of 44° generation won 71.0 over 100 matches
#
#   4%|▍         | 44/1000 [03:00<1:01:42,  3.87s/it]INFO:root:
# Best Agent of 45° generation won 71.0 over 100 matches
#
#   4%|▍         | 45/1000 [03:04<1:01:32,  3.87s/it]INFO:root:
# Best Agent of 46° generation won 71.0 over 100 matches
#
#   5%|▍         | 46/1000 [03:07<1:01:35,  3.87s/it]INFO:root:
# Best Agent of 47° generation won 71.0 over 100 matches
#
#   5%|▍         | 47/1000 [03:12<1:02:35,  3.94s/it]INFO:root:
# Best Agent of 48° generation won 71.0 over 100 matches
#
#   5%|▍         | 48/1000 [03:15<1:02:27,  3.94s/it]INFO:root:
# Best Agent of 49° generation won 71.0 over 100 matches
#
#   5%|▍         | 49/1000 [03:19<1:01:54,  3.91s/it]INFO:root:
# Best Agent of 50° generation won 71.0 over 100 matches
#
#   5%|▌         | 50/1000 [03:23<1:01:37,  3.89s/it]INFO:root:
# Best Agent of 51° generation won 71.0 over 100 matches
#
#   5%|▌         | 51/1000 [03:27<1:01:35,  3.89s/it]INFO:root:
# Best Agent of 52° generation won 71.0 over 100 matches
#
#   5%|▌         | 52/1000 [03:31<1:01:52,  3.92s/it]INFO:root:
# Best Agent of 53° generation won 71.0 over 100 matches
#
#   5%|▌         | 53/1000 [03:36<1:08:35,  4.35s/it]INFO:root:
# Best Agent of 54° generation won 71.0 over 100 matches
#
#   5%|▌         | 54/1000 [03:42<1:14:58,  4.76s/it]INFO:root:
# Best Agent of 55° generation won 71.0 over 100 matches
#
#   6%|▌         | 55/1000 [03:47<1:14:45,  4.75s/it]INFO:root:
# Best Agent of 56° generation won 71.0 over 100 matches
#
#   6%|▌         | 56/1000 [03:51<1:12:13,  4.59s/it]INFO:root:
# Best Agent of 57° generation won 71.0 over 100 matches
#
#   6%|▌         | 57/1000 [03:55<1:08:43,  4.37s/it]INFO:root:
# Best Agent of 58° generation won 71.0 over 100 matches
#
#   6%|▌         | 58/1000 [03:59<1:06:12,  4.22s/it]INFO:root:
# Best Agent of 59° generation won 71.0 over 100 matches
#
#   6%|▌         | 59/1000 [04:03<1:04:11,  4.09s/it]INFO:root:
# Best Agent of 60° generation won 71.0 over 100 matches
#
#   6%|▌         | 60/1000 [04:06<1:03:01,  4.02s/it]INFO:root:
# Best Agent of 61° generation won 71.0 over 100 matches
#
#   6%|▌         | 61/1000 [04:10<1:01:51,  3.95s/it]INFO:root:
# Best Agent of 62° generation won 71.0 over 100 matches
#
#   6%|▌         | 62/1000 [04:14<1:01:08,  3.91s/it]INFO:root:
# Best Agent of 63° generation won 71.0 over 100 matches
#
#   6%|▋         | 63/1000 [04:18<1:00:40,  3.89s/it]INFO:root:
# Best Agent of 64° generation won 71.0 over 100 matches
#
#   6%|▋         | 64/1000 [04:22<1:00:56,  3.91s/it]INFO:root:
# Best Agent of 65° generation won 71.0 over 100 matches
#
#   6%|▋         | 65/1000 [04:26<1:00:36,  3.89s/it]INFO:root:
# Best Agent of 66° generation won 71.0 over 100 matches
#
#   7%|▋         | 66/1000 [04:29<1:00:23,  3.88s/it]INFO:root:
# Best Agent of 67° generation won 71.0 over 100 matches
#
#   7%|▋         | 67/1000 [04:34<1:02:22,  4.01s/it]INFO:root:
# Best Agent of 68° generation won 71.0 over 100 matches
#
#   7%|▋         | 68/1000 [04:38<1:03:30,  4.09s/it]INFO:root:
# Best Agent of 69° generation won 71.0 over 100 matches
#
#   7%|▋         | 69/1000 [04:42<1:03:05,  4.07s/it]INFO:root:
# Best Agent of 70° generation won 71.0 over 100 matches
#
#   7%|▋         | 70/1000 [04:46<1:01:41,  3.98s/it]INFO:root:
# Best Agent of 71° generation won 71.0 over 100 matches
#
#   7%|▋         | 71/1000 [04:50<1:00:46,  3.93s/it]INFO:root:
# Best Agent of 72° generation won 71.0 over 100 matches
#
#   7%|▋         | 72/1000 [04:53<59:58,  3.88s/it]  INFO:root:
# Best Agent of 73° generation won 71.0 over 100 matches
#
#   7%|▋         | 73/1000 [04:57<59:28,  3.85s/it]INFO:root:
# Best Agent of 74° generation won 71.0 over 100 matches
#
#   7%|▋         | 74/1000 [05:01<59:37,  3.86s/it]INFO:root:
# Best Agent of 75° generation won 71.0 over 100 matches
#
#   8%|▊         | 75/1000 [05:05<59:16,  3.85s/it]INFO:root:
# Best Agent of 76° generation won 71.0 over 100 matches
#
#   8%|▊         | 76/1000 [05:09<59:35,  3.87s/it]INFO:root:
# Best Agent of 77° generation won 71.0 over 100 matches
#
#   8%|▊         | 77/1000 [05:13<59:53,  3.89s/it]INFO:root:
# Best Agent of 78° generation won 71.0 over 100 matches
#
#   8%|▊         | 78/1000 [05:17<59:57,  3.90s/it]INFO:root:
# Best Agent of 79° generation won 71.0 over 100 matches
#
#   8%|▊         | 79/1000 [05:21<1:00:06,  3.92s/it]INFO:root:
# Best Agent of 80° generation won 71.0 over 100 matches
#
#   8%|▊         | 80/1000 [05:25<1:00:16,  3.93s/it]INFO:root:
# Best Agent of 81° generation won 71.0 over 100 matches
#
#   8%|▊         | 81/1000 [05:29<1:00:04,  3.92s/it]INFO:root:
# Best Agent of 82° generation won 71.0 over 100 matches
#
#   8%|▊         | 82/1000 [05:33<1:02:09,  4.06s/it]INFO:root:
# Best Agent of 83° generation won 71.0 over 100 matches
#
#   8%|▊         | 83/1000 [05:37<1:03:33,  4.16s/it]INFO:root:
# Best Agent of 84° generation won 71.0 over 100 matches
#
#   8%|▊         | 84/1000 [05:42<1:08:05,  4.46s/it]INFO:root:
# Best Agent of 85° generation won 71.0 over 100 matches
#
#   8%|▊         | 85/1000 [05:47<1:10:10,  4.60s/it]INFO:root:
# Best Agent of 86° generation won 71.0 over 100 matches
#
#   9%|▊         | 86/1000 [05:52<1:10:22,  4.62s/it]INFO:root:
# Best Agent of 87° generation won 71.0 over 100 matches
#
#   9%|▊         | 87/1000 [05:56<1:07:50,  4.46s/it]INFO:root:
# Best Agent of 88° generation won 71.0 over 100 matches
#
#   9%|▉         | 88/1000 [06:01<1:08:08,  4.48s/it]INFO:root:
# Best Agent of 89° generation won 71.0 over 100 matches
#
#   9%|▉         | 89/1000 [06:06<1:13:44,  4.86s/it]INFO:root:
# Best Agent of 90° generation won 71.0 over 100 matches
#
#   9%|▉         | 90/1000 [06:13<1:23:21,  5.50s/it]INFO:root:
# Best Agent of 91° generation won 71.0 over 100 matches
#
#   9%|▉         | 91/1000 [06:26<1:56:36,  7.70s/it]INFO:root:
# Best Agent of 92° generation won 71.0 over 100 matches
#
#   9%|▉         | 92/1000 [06:31<1:44:50,  6.93s/it]INFO:root:
# Best Agent of 93° generation won 71.0 over 100 matches
#
#   9%|▉         | 93/1000 [06:36<1:35:56,  6.35s/it]INFO:root:
# Best Agent of 94° generation won 71.0 over 100 matches
#
#   9%|▉         | 94/1000 [06:42<1:30:54,  6.02s/it]INFO:root:
# Best Agent of 95° generation won 71.0 over 100 matches
#
#  10%|▉         | 95/1000 [06:48<1:31:27,  6.06s/it]INFO:root:
# Best Agent of 96° generation won 71.0 over 100 matches
#
#  10%|▉         | 96/1000 [06:53<1:27:39,  5.82s/it]INFO:root:
# Best Agent of 97° generation won 71.0 over 100 matches
#
#  10%|▉         | 97/1000 [06:59<1:26:32,  5.75s/it]INFO:root:
# Best Agent of 98° generation won 71.0 over 100 matches
#
#  10%|▉         | 98/1000 [07:04<1:26:09,  5.73s/it]INFO:root:
# Best Agent of 99° generation won 71.0 over 100 matches
#
#  10%|▉         | 99/1000 [07:10<1:24:33,  5.63s/it]INFO:root:
# Best Agent of 100° generation won 71.0 over 100 matches
#
#  10%|█         | 100/1000 [07:15<1:24:40,  5.64s/it]INFO:root:
# Best Agent of 101° generation won 71.0 over 100 matches
#
#  10%|█         | 101/1000 [07:21<1:22:50,  5.53s/it]INFO:root:
# Best Agent of 102° generation won 71.0 over 100 matches
#
#  10%|█         | 102/1000 [07:27<1:25:04,  5.68s/it]INFO:root:
# Best Agent of 103° generation won 71.0 over 100 matches
#
#  10%|█         | 103/1000 [07:32<1:23:25,  5.58s/it]INFO:root:
# Best Agent of 104° generation won 71.0 over 100 matches
#
#  10%|█         | 104/1000 [07:38<1:22:55,  5.55s/it]INFO:root:
# Best Agent of 105° generation won 71.0 over 100 matches
#
#  10%|█         | 105/1000 [07:43<1:24:08,  5.64s/it]INFO:root:
# Best Agent of 106° generation won 71.0 over 100 matches
#
#  11%|█         | 106/1000 [07:49<1:23:31,  5.61s/it]INFO:root:
# Best Agent of 107° generation won 71.0 over 100 matches
#
#  11%|█         | 107/1000 [07:54<1:23:17,  5.60s/it]INFO:root:
# Best Agent of 108° generation won 71.0 over 100 matches
#
#  11%|█         | 108/1000 [08:00<1:23:43,  5.63s/it]INFO:root:
# Best Agent of 109° generation won 71.0 over 100 matches
#
#  11%|█         | 109/1000 [08:06<1:22:51,  5.58s/it]INFO:root:
# Best Agent of 110° generation won 71.0 over 100 matches
#
#  11%|█         | 110/1000 [08:11<1:22:55,  5.59s/it]INFO:root:
# Best Agent of 111° generation won 71.0 over 100 matches
#
#  11%|█         | 111/1000 [08:17<1:25:32,  5.77s/it]INFO:root:
# Best Agent of 112° generation won 71.0 over 100 matches
#
#  11%|█         | 112/1000 [08:23<1:23:38,  5.65s/it]INFO:root:
# Best Agent of 113° generation won 71.0 over 100 matches
#
#  11%|█▏        | 113/1000 [08:28<1:21:49,  5.54s/it]INFO:root:
# Best Agent of 114° generation won 71.0 over 100 matches
#
#  11%|█▏        | 114/1000 [08:33<1:20:58,  5.48s/it]INFO:root:
# Best Agent of 115° generation won 71.0 over 100 matches
#
#  12%|█▏        | 115/1000 [08:39<1:20:18,  5.44s/it]INFO:root:
# Best Agent of 116° generation won 71.0 over 100 matches
#
#  12%|█▏        | 116/1000 [08:44<1:19:34,  5.40s/it]INFO:root:
# Best Agent of 117° generation won 71.0 over 100 matches
#
#  12%|█▏        | 117/1000 [08:50<1:19:53,  5.43s/it]INFO:root:
# Best Agent of 118° generation won 71.0 over 100 matches
#
#  12%|█▏        | 118/1000 [09:09<2:22:18,  9.68s/it]INFO:root:
# Best Agent of 119° generation won 71.0 over 100 matches
#
#  12%|█▏        | 119/1000 [09:19<2:20:34,  9.57s/it]INFO:root:
# Best Agent of 120° generation won 71.0 over 100 matches
#
#  12%|█▏        | 120/1000 [09:24<2:04:17,  8.47s/it]INFO:root:
# Best Agent of 121° generation won 71.0 over 100 matches
#
#  12%|█▏        | 121/1000 [09:30<1:51:12,  7.59s/it]INFO:root:
# Best Agent of 122° generation won 71.0 over 100 matches
#
#  12%|█▏        | 122/1000 [09:35<1:41:34,  6.94s/it]INFO:root:
# Best Agent of 123° generation won 71.0 over 100 matches
#
#  12%|█▏        | 123/1000 [09:41<1:35:34,  6.54s/it]INFO:root:
# Best Agent of 124° generation won 71.0 over 100 matches
#
#  12%|█▏        | 124/1000 [09:46<1:26:57,  5.96s/it]INFO:root:
# Best Agent of 125° generation won 71.0 over 100 matches
#
#  12%|█▎        | 125/1000 [09:50<1:20:16,  5.50s/it]INFO:root:
# Best Agent of 126° generation won 71.0 over 100 matches
#
#  13%|█▎        | 126/1000 [09:54<1:14:25,  5.11s/it]INFO:root:
# Best Agent of 127° generation won 71.0 over 100 matches
#
#  13%|█▎        | 127/1000 [09:58<1:09:50,  4.80s/it]INFO:root:
# Best Agent of 128° generation won 71.0 over 100 matches
#
#  13%|█▎        | 128/1000 [10:03<1:07:24,  4.64s/it]INFO:root:
# Best Agent of 129° generation won 71.0 over 100 matches
#
#  13%|█▎        | 129/1000 [10:07<1:04:58,  4.48s/it]INFO:root:
# Best Agent of 130° generation won 71.0 over 100 matches
#
#  13%|█▎        | 130/1000 [10:11<1:03:27,  4.38s/it]INFO:root:
# Best Agent of 131° generation won 71.0 over 100 matches
#
#  13%|█▎        | 131/1000 [10:15<1:02:36,  4.32s/it]INFO:root:
# Best Agent of 132° generation won 71.0 over 100 matches
#
#  13%|█▎        | 132/1000 [10:19<1:00:36,  4.19s/it]INFO:root:
# Best Agent of 133° generation won 71.0 over 100 matches
#
#  13%|█▎        | 133/1000 [10:23<59:15,  4.10s/it]  INFO:root:
# Best Agent of 134° generation won 71.0 over 100 matches
#
#  13%|█▎        | 134/1000 [10:27<58:28,  4.05s/it]INFO:root:
# Best Agent of 135° generation won 71.0 over 100 matches
#
#  14%|█▎        | 135/1000 [10:31<57:47,  4.01s/it]INFO:root:
# Best Agent of 136° generation won 71.0 over 100 matches
#
#  14%|█▎        | 136/1000 [10:35<57:32,  4.00s/it]INFO:root:
# Best Agent of 137° generation won 71.0 over 100 matches
#
#  14%|█▎        | 137/1000 [10:39<57:16,  3.98s/it]INFO:root:
# Best Agent of 138° generation won 71.0 over 100 matches
#
#  14%|█▍        | 138/1000 [10:42<57:05,  3.97s/it]INFO:root:
# Best Agent of 139° generation won 71.0 over 100 matches
#
#  14%|█▍        | 139/1000 [10:46<57:06,  3.98s/it]INFO:root:
# Best Agent of 140° generation won 71.0 over 100 matches
#
#  14%|█▍        | 140/1000 [10:50<57:04,  3.98s/it]INFO:root:
# Best Agent of 141° generation won 71.0 over 100 matches
#
#  14%|█▍        | 141/1000 [10:55<57:28,  4.01s/it]INFO:root:
# Best Agent of 142° generation won 71.0 over 100 matches
#
#  14%|█▍        | 142/1000 [10:59<57:28,  4.02s/it]INFO:root:
# Best Agent of 143° generation won 71.0 over 100 matches
#
#  14%|█▍        | 143/1000 [11:03<57:14,  4.01s/it]INFO:root:
# Best Agent of 144° generation won 71.0 over 100 matches
#
#  14%|█▍        | 144/1000 [11:06<56:19,  3.95s/it]INFO:root:
# Best Agent of 145° generation won 71.0 over 100 matches
#
#  14%|█▍        | 145/1000 [11:10<55:31,  3.90s/it]INFO:root:
# Best Agent of 146° generation won 71.0 over 100 matches
#
#  15%|█▍        | 146/1000 [11:14<55:35,  3.91s/it]INFO:root:
# Best Agent of 147° generation won 71.0 over 100 matches
#
#  15%|█▍        | 147/1000 [11:18<55:08,  3.88s/it]INFO:root:
# Best Agent of 148° generation won 71.0 over 100 matches
#
#  15%|█▍        | 148/1000 [11:22<54:23,  3.83s/it]INFO:root:
# Best Agent of 149° generation won 71.0 over 100 matches
#
#  15%|█▍        | 149/1000 [11:25<54:03,  3.81s/it]INFO:root:
# Best Agent of 150° generation won 71.0 over 100 matches
#
#  15%|█▌        | 150/1000 [11:29<53:43,  3.79s/it]INFO:root:
# Best Agent of 151° generation won 71.0 over 100 matches
#
#  15%|█▌        | 151/1000 [11:33<54:26,  3.85s/it]INFO:root:
# Best Agent of 152° generation won 71.0 over 100 matches
#
#  15%|█▌        | 152/1000 [11:37<55:11,  3.91s/it]INFO:root:
# Best Agent of 153° generation won 71.0 over 100 matches
#
#  15%|█▌        | 153/1000 [11:42<1:00:31,  4.29s/it]INFO:root:
# Best Agent of 154° generation won 71.0 over 100 matches
#
#  15%|█▌        | 154/1000 [11:48<1:05:16,  4.63s/it]INFO:root:
# Best Agent of 155° generation won 71.0 over 100 matches
#
#  16%|█▌        | 155/1000 [11:53<1:06:42,  4.74s/it]INFO:root:
# Best Agent of 156° generation won 71.0 over 100 matches
#
#  16%|█▌        | 156/1000 [12:01<1:19:34,  5.66s/it]INFO:root:
# Best Agent of 157° generation won 71.0 over 100 matches
#
#  16%|█▌        | 157/1000 [12:06<1:17:37,  5.52s/it]INFO:root:
# Best Agent of 158° generation won 71.0 over 100 matches
#
#  16%|█▌        | 158/1000 [12:17<1:42:15,  7.29s/it]INFO:root:
# Best Agent of 159° generation won 71.0 over 100 matches
#
#  16%|█▌        | 159/1000 [12:27<1:52:55,  8.06s/it]INFO:root:
# Best Agent of 160° generation won 71.0 over 100 matches
#
#  16%|█▌        | 160/1000 [12:34<1:47:46,  7.70s/it]INFO:root:
# Best Agent of 161° generation won 71.0 over 100 matches
#
#  16%|█▌        | 161/1000 [12:40<1:39:40,  7.13s/it]INFO:root:
# Best Agent of 162° generation won 71.0 over 100 matches
#
#  16%|█▌        | 162/1000 [12:48<1:46:32,  7.63s/it]INFO:root:
# Best Agent of 163° generation won 71.0 over 100 matches
#
#  16%|█▋        | 163/1000 [12:54<1:36:34,  6.92s/it]INFO:root:
# Best Agent of 164° generation won 71.0 over 100 matches
#
#  16%|█▋        | 164/1000 [12:58<1:24:39,  6.08s/it]INFO:root:
# Best Agent of 165° generation won 71.0 over 100 matches
#
#  16%|█▋        | 165/1000 [13:02<1:15:38,  5.44s/it]INFO:root:
# Best Agent of 166° generation won 71.0 over 100 matches
#
#  17%|█▋        | 166/1000 [13:08<1:17:00,  5.54s/it]INFO:root:
# Best Agent of 167° generation won 71.0 over 100 matches
#
#  17%|█▋        | 167/1000 [13:12<1:13:45,  5.31s/it]INFO:root:
# Best Agent of 168° generation won 71.0 over 100 matches
#
#  17%|█▋        | 168/1000 [13:17<1:08:54,  4.97s/it]INFO:root:
# Best Agent of 169° generation won 71.0 over 100 matches
#
#  17%|█▋        | 169/1000 [13:20<1:04:35,  4.66s/it]INFO:root:
# Best Agent of 170° generation won 71.0 over 100 matches
#
#  17%|█▋        | 170/1000 [13:24<1:01:42,  4.46s/it]INFO:root:
# Best Agent of 171° generation won 71.0 over 100 matches
#
#  17%|█▋        | 171/1000 [13:28<59:44,  4.32s/it]  INFO:root:
# Best Agent of 172° generation won 71.0 over 100 matches
#
#  17%|█▋        | 172/1000 [13:35<1:07:20,  4.88s/it]INFO:root:
# Best Agent of 173° generation won 71.0 over 100 matches
#
#  17%|█▋        | 173/1000 [13:39<1:05:53,  4.78s/it]INFO:root:
# Best Agent of 174° generation won 71.0 over 100 matches
#
#  17%|█▋        | 174/1000 [13:44<1:04:28,  4.68s/it]INFO:root:
# Best Agent of 175° generation won 71.0 over 100 matches
#
#  18%|█▊        | 175/1000 [13:48<1:01:46,  4.49s/it]INFO:root:
# Best Agent of 176° generation won 71.0 over 100 matches
#
#  18%|█▊        | 176/1000 [13:52<1:00:08,  4.38s/it]INFO:root:
# Best Agent of 177° generation won 71.0 over 100 matches
#
#  18%|█▊        | 177/1000 [13:56<1:00:10,  4.39s/it]INFO:root:
# Best Agent of 178° generation won 71.0 over 100 matches
#
#  18%|█▊        | 178/1000 [14:03<1:12:00,  5.26s/it]INFO:root:
# Best Agent of 179° generation won 71.0 over 100 matches
#
#  18%|█▊        | 179/1000 [14:10<1:18:21,  5.73s/it]INFO:root:
# Best Agent of 180° generation won 71.0 over 100 matches
#
#  18%|█▊        | 180/1000 [14:15<1:12:01,  5.27s/it]INFO:root:
# Best Agent of 181° generation won 71.0 over 100 matches
#
#  18%|█▊        | 181/1000 [14:21<1:17:07,  5.65s/it]INFO:root:
# Best Agent of 182° generation won 71.0 over 100 matches
#
#  18%|█▊        | 182/1000 [14:27<1:19:12,  5.81s/it]INFO:root:
# Best Agent of 183° generation won 71.0 over 100 matches
#
#  18%|█▊        | 183/1000 [14:32<1:15:20,  5.53s/it]INFO:root:
# Best Agent of 184° generation won 71.0 over 100 matches
#
#  18%|█▊        | 184/1000 [14:38<1:15:31,  5.55s/it]INFO:root:
# Best Agent of 185° generation won 71.0 over 100 matches
#
#  18%|█▊        | 185/1000 [14:44<1:18:05,  5.75s/it]INFO:root:
# Best Agent of 186° generation won 71.0 over 100 matches
#
#  19%|█▊        | 186/1000 [14:50<1:19:27,  5.86s/it]INFO:root:
# Best Agent of 187° generation won 71.0 over 100 matches
#
#  19%|█▊        | 187/1000 [14:54<1:12:20,  5.34s/it]INFO:root:
# Best Agent of 188° generation won 71.0 over 100 matches
#
#  19%|█▉        | 188/1000 [14:58<1:06:59,  4.95s/it]INFO:root:
# Best Agent of 189° generation won 71.0 over 100 matches
#
#  19%|█▉        | 189/1000 [15:02<1:04:04,  4.74s/it]INFO:root:
# Best Agent of 190° generation won 71.0 over 100 matches
#
#  19%|█▉        | 190/1000 [15:06<1:00:39,  4.49s/it]INFO:root:
# Best Agent of 191° generation won 71.0 over 100 matches
#
#  19%|█▉        | 191/1000 [15:10<58:14,  4.32s/it]  INFO:root:
# Best Agent of 192° generation won 71.0 over 100 matches
#
#  19%|█▉        | 192/1000 [15:14<56:37,  4.21s/it]INFO:root:
# Best Agent of 193° generation won 71.0 over 100 matches
#
#  19%|█▉        | 193/1000 [15:18<55:49,  4.15s/it]INFO:root:
# Best Agent of 194° generation won 71.0 over 100 matches
#
#  19%|█▉        | 194/1000 [15:22<54:34,  4.06s/it]INFO:root:
# Best Agent of 195° generation won 71.0 over 100 matches
#
#  20%|█▉        | 195/1000 [15:26<53:31,  3.99s/it]INFO:root:
# Best Agent of 196° generation won 71.0 over 100 matches
#
#  20%|█▉        | 196/1000 [15:30<52:41,  3.93s/it]INFO:root:
# Best Agent of 197° generation won 71.0 over 100 matches
#
#  20%|█▉        | 197/1000 [15:33<51:54,  3.88s/it]INFO:root:
# Best Agent of 198° generation won 71.0 over 100 matches
#
#  20%|█▉        | 198/1000 [15:37<52:03,  3.90s/it]INFO:root:
# Best Agent of 199° generation won 71.0 over 100 matches
#
#  20%|█▉        | 199/1000 [15:41<51:50,  3.88s/it]INFO:root:
# Best Agent of 200° generation won 71.0 over 100 matches
#
#  20%|██        | 200/1000 [15:45<52:09,  3.91s/it]INFO:root:
# Best Agent of 201° generation won 71.0 over 100 matches
#
#  20%|██        | 201/1000 [15:50<54:27,  4.09s/it]INFO:root:
# Best Agent of 202° generation won 71.0 over 100 matches
#
#  20%|██        | 202/1000 [15:54<53:26,  4.02s/it]INFO:root:
# Best Agent of 203° generation won 71.0 over 100 matches
#
#  20%|██        | 203/1000 [15:58<53:51,  4.05s/it]INFO:root:
# Best Agent of 204° generation won 71.0 over 100 matches
#
#  20%|██        | 204/1000 [16:02<53:41,  4.05s/it]INFO:root:
# Best Agent of 205° generation won 71.0 over 100 matches
#
#  20%|██        | 205/1000 [16:06<52:36,  3.97s/it]INFO:root:
# Best Agent of 206° generation won 71.0 over 100 matches
#
#  21%|██        | 206/1000 [16:10<52:42,  3.98s/it]INFO:root:
# Best Agent of 207° generation won 71.0 over 100 matches
#
#  21%|██        | 207/1000 [16:14<52:42,  3.99s/it]INFO:root:
# Best Agent of 208° generation won 71.0 over 100 matches
#
#  21%|██        | 208/1000 [16:18<52:56,  4.01s/it]INFO:root:
# Best Agent of 209° generation won 71.0 over 100 matches
#
#  21%|██        | 209/1000 [16:22<53:56,  4.09s/it]INFO:root:
# Best Agent of 210° generation won 71.0 over 100 matches
#
#  21%|██        | 210/1000 [16:26<53:39,  4.08s/it]INFO:root:
# Best Agent of 211° generation won 71.0 over 100 matches
#
#  21%|██        | 211/1000 [16:30<53:13,  4.05s/it]INFO:root:
# Best Agent of 212° generation won 71.0 over 100 matches
#
#  21%|██        | 212/1000 [16:34<53:47,  4.10s/it]INFO:root:
# Best Agent of 213° generation won 71.0 over 100 matches
#
#  21%|██▏       | 213/1000 [16:38<53:23,  4.07s/it]INFO:root:
# Best Agent of 214° generation won 71.0 over 100 matches
#
#  21%|██▏       | 214/1000 [16:43<54:54,  4.19s/it]INFO:root:
# Best Agent of 215° generation won 71.0 over 100 matches
#
#  22%|██▏       | 215/1000 [16:47<55:54,  4.27s/it]INFO:root:
# Best Agent of 216° generation won 71.0 over 100 matches
#
#  22%|██▏       | 216/1000 [16:51<54:42,  4.19s/it]INFO:root:
# Best Agent of 217° generation won 71.0 over 100 matches
#
#  22%|██▏       | 217/1000 [16:55<53:44,  4.12s/it]INFO:root:
# Best Agent of 218° generation won 71.0 over 100 matches
#
#  22%|██▏       | 218/1000 [16:59<52:49,  4.05s/it]INFO:root:
# Best Agent of 219° generation won 71.0 over 100 matches
#
#  22%|██▏       | 219/1000 [17:03<51:35,  3.96s/it]INFO:root:
# Best Agent of 220° generation won 71.0 over 100 matches
#
#  22%|██▏       | 220/1000 [17:07<51:14,  3.94s/it]INFO:root:
# Best Agent of 221° generation won 71.0 over 100 matches
#
#  22%|██▏       | 221/1000 [17:11<51:03,  3.93s/it]INFO:root:
# Best Agent of 222° generation won 71.0 over 100 matches
#
#  22%|██▏       | 222/1000 [17:17<59:26,  4.58s/it]INFO:root:
# Best Agent of 223° generation won 71.0 over 100 matches
#
#  22%|██▏       | 223/1000 [17:22<1:02:32,  4.83s/it]INFO:root:
# Best Agent of 224° generation won 71.0 over 100 matches
#
#  22%|██▏       | 224/1000 [17:28<1:05:25,  5.06s/it]INFO:root:
# Best Agent of 225° generation won 71.0 over 100 matches
#
#  22%|██▎       | 225/1000 [17:34<1:10:09,  5.43s/it]INFO:root:
# Best Agent of 226° generation won 71.0 over 100 matches
#
#  23%|██▎       | 226/1000 [17:39<1:10:35,  5.47s/it]INFO:root:
# Best Agent of 227° generation won 71.0 over 100 matches
#
#  23%|██▎       | 227/1000 [17:44<1:06:17,  5.15s/it]INFO:root:
# Best Agent of 228° generation won 71.0 over 100 matches
#
#  23%|██▎       | 228/1000 [17:48<1:03:41,  4.95s/it]INFO:root:
# Best Agent of 229° generation won 71.0 over 100 matches
#
#  23%|██▎       | 229/1000 [17:53<1:01:20,  4.77s/it]INFO:root:
# Best Agent of 230° generation won 71.0 over 100 matches
#
#  23%|██▎       | 230/1000 [17:57<1:00:13,  4.69s/it]INFO:root:
# Best Agent of 231° generation won 71.0 over 100 matches
#
#  23%|██▎       | 231/1000 [18:02<59:15,  4.62s/it]  INFO:root:
# Best Agent of 232° generation won 71.0 over 100 matches
#
#  23%|██▎       | 232/1000 [18:06<58:55,  4.60s/it]INFO:root:
# Best Agent of 233° generation won 71.0 over 100 matches
#
#  23%|██▎       | 233/1000 [18:11<58:40,  4.59s/it]INFO:root:
# Best Agent of 234° generation won 71.0 over 100 matches
#
#  23%|██▎       | 234/1000 [18:16<1:00:52,  4.77s/it]INFO:root:
# Best Agent of 235° generation won 71.0 over 100 matches
#
#  24%|██▎       | 235/1000 [18:21<1:00:17,  4.73s/it]INFO:root:
# Best Agent of 236° generation won 71.0 over 100 matches
#
#  24%|██▎       | 236/1000 [18:26<1:01:28,  4.83s/it]INFO:root:
# Best Agent of 237° generation won 71.0 over 100 matches
#
#  24%|██▎       | 237/1000 [18:30<59:13,  4.66s/it]  INFO:root:
# Best Agent of 238° generation won 71.0 over 100 matches
#
#  24%|██▍       | 238/1000 [18:34<58:11,  4.58s/it]INFO:root:
# Best Agent of 239° generation won 71.0 over 100 matches
#
#  24%|██▍       | 239/1000 [18:39<58:47,  4.64s/it]INFO:root:
# Best Agent of 240° generation won 71.0 over 100 matches
#
#  24%|██▍       | 240/1000 [18:43<57:06,  4.51s/it]INFO:root:
# Best Agent of 241° generation won 71.0 over 100 matches
#
#  24%|██▍       | 241/1000 [18:48<57:02,  4.51s/it]INFO:root:
# Best Agent of 242° generation won 71.0 over 100 matches
#
#  24%|██▍       | 242/1000 [18:52<56:33,  4.48s/it]INFO:root:
# Best Agent of 243° generation won 71.0 over 100 matches
#
#  24%|██▍       | 243/1000 [18:57<55:44,  4.42s/it]INFO:root:
# Best Agent of 244° generation won 71.0 over 100 matches
#
#  24%|██▍       | 244/1000 [19:01<54:36,  4.33s/it]INFO:root:
# Best Agent of 245° generation won 71.0 over 100 matches
#
#  24%|██▍       | 245/1000 [19:05<53:41,  4.27s/it]INFO:root:
# Best Agent of 246° generation won 71.0 over 100 matches
#
#  25%|██▍       | 246/1000 [19:09<53:08,  4.23s/it]INFO:root:
# Best Agent of 247° generation won 71.0 over 100 matches
#
#  25%|██▍       | 247/1000 [19:13<53:08,  4.23s/it]INFO:root:
# Best Agent of 248° generation won 71.0 over 100 matches
#
#  25%|██▍       | 248/1000 [19:17<52:57,  4.23s/it]INFO:root:
# Best Agent of 249° generation won 71.0 over 100 matches
#
#  25%|██▍       | 249/1000 [19:21<52:24,  4.19s/it]INFO:root:
# Best Agent of 250° generation won 71.0 over 100 matches
#
#  25%|██▌       | 250/1000 [19:26<52:54,  4.23s/it]INFO:root:
# Best Agent of 251° generation won 71.0 over 100 matches
#
#  25%|██▌       | 251/1000 [19:30<53:43,  4.30s/it]INFO:root:
# Best Agent of 252° generation won 71.0 over 100 matches
#
#  25%|██▌       | 252/1000 [19:35<53:40,  4.31s/it]INFO:root:
# Best Agent of 253° generation won 71.0 over 100 matches
#
#  25%|██▌       | 253/1000 [19:39<53:12,  4.27s/it]INFO:root:
# Best Agent of 254° generation won 71.0 over 100 matches
#
#  25%|██▌       | 254/1000 [19:43<53:10,  4.28s/it]INFO:root:
# Best Agent of 255° generation won 71.0 over 100 matches
#
#  26%|██▌       | 255/1000 [19:47<52:34,  4.23s/it]INFO:root:
# Best Agent of 256° generation won 71.0 over 100 matches
#
#  26%|██▌       | 256/1000 [19:51<52:25,  4.23s/it]INFO:root:
# Best Agent of 257° generation won 71.0 over 100 matches
#
#  26%|██▌       | 257/1000 [19:56<52:11,  4.21s/it]INFO:root:
# Best Agent of 258° generation won 71.0 over 100 matches
#
#  26%|██▌       | 258/1000 [20:00<53:01,  4.29s/it]INFO:root:
# Best Agent of 259° generation won 71.0 over 100 matches
#
#  26%|██▌       | 259/1000 [20:04<52:54,  4.28s/it]INFO:root:
# Best Agent of 260° generation won 71.0 over 100 matches
#
#  26%|██▌       | 260/1000 [20:09<53:16,  4.32s/it]INFO:root:
# Best Agent of 261° generation won 71.0 over 100 matches
#
#  26%|██▌       | 261/1000 [20:13<53:27,  4.34s/it]INFO:root:
# Best Agent of 262° generation won 71.0 over 100 matches
#
#  26%|██▌       | 262/1000 [20:17<53:09,  4.32s/it]INFO:root:
# Best Agent of 263° generation won 71.0 over 100 matches
#
#  26%|██▋       | 263/1000 [20:22<53:10,  4.33s/it]INFO:root:
# Best Agent of 264° generation won 71.0 over 100 matches
#
#  26%|██▋       | 264/1000 [20:26<52:48,  4.30s/it]INFO:root:
# Best Agent of 265° generation won 71.0 over 100 matches
#
#  26%|██▋       | 265/1000 [20:30<52:44,  4.31s/it]INFO:root:
# Best Agent of 266° generation won 71.0 over 100 matches
#
#  27%|██▋       | 266/1000 [20:35<52:35,  4.30s/it]INFO:root:
# Best Agent of 267° generation won 71.0 over 100 matches
#
#  27%|██▋       | 267/1000 [20:39<53:05,  4.35s/it]INFO:root:
# Best Agent of 268° generation won 71.0 over 100 matches
#
#  27%|██▋       | 268/1000 [20:43<52:08,  4.27s/it]INFO:root:
# Best Agent of 269° generation won 71.0 over 100 matches
#
#  27%|██▋       | 269/1000 [20:47<51:15,  4.21s/it]INFO:root:
# Best Agent of 270° generation won 71.0 over 100 matches
#
#  27%|██▋       | 270/1000 [20:51<51:08,  4.20s/it]INFO:root:
# Best Agent of 271° generation won 71.0 over 100 matches
#
#  27%|██▋       | 271/1000 [20:55<49:55,  4.11s/it]INFO:root:
# Best Agent of 272° generation won 71.0 over 100 matches
#
#  27%|██▋       | 272/1000 [20:59<49:39,  4.09s/it]INFO:root:
# Best Agent of 273° generation won 71.0 over 100 matches
#
#  27%|██▋       | 273/1000 [21:03<49:34,  4.09s/it]INFO:root:
# Best Agent of 274° generation won 71.0 over 100 matches
#
#  27%|██▋       | 274/1000 [21:07<48:51,  4.04s/it]INFO:root:
# Best Agent of 275° generation won 71.0 over 100 matches
#
#  28%|██▊       | 275/1000 [21:11<48:14,  3.99s/it]INFO:root:
# Best Agent of 276° generation won 71.0 over 100 matches
#
#  28%|██▊       | 276/1000 [21:15<47:58,  3.98s/it]INFO:root:
# Best Agent of 277° generation won 71.0 over 100 matches
#
#  28%|██▊       | 277/1000 [21:19<48:09,  4.00s/it]INFO:root:
# Best Agent of 278° generation won 71.0 over 100 matches
#
#  28%|██▊       | 278/1000 [21:23<47:49,  3.97s/it]INFO:root:
# Best Agent of 279° generation won 71.0 over 100 matches
#
#  28%|██▊       | 279/1000 [21:27<47:54,  3.99s/it]INFO:root:
# Best Agent of 280° generation won 71.0 over 100 matches
#
#  28%|██▊       | 280/1000 [21:31<47:29,  3.96s/it]INFO:root:
# Best Agent of 281° generation won 71.0 over 100 matches
#
#  28%|██▊       | 281/1000 [21:35<47:52,  3.99s/it]INFO:root:
# Best Agent of 282° generation won 71.0 over 100 matches
#
#  28%|██▊       | 282/1000 [21:39<48:04,  4.02s/it]INFO:root:
# Best Agent of 283° generation won 71.0 over 100 matches
#
#  28%|██▊       | 283/1000 [21:43<48:07,  4.03s/it]INFO:root:
# Best Agent of 284° generation won 71.0 over 100 matches
#
#  28%|██▊       | 284/1000 [21:47<48:34,  4.07s/it]INFO:root:
# Best Agent of 285° generation won 71.0 over 100 matches
#
#  28%|██▊       | 285/1000 [21:51<48:37,  4.08s/it]INFO:root:
# Best Agent of 286° generation won 71.0 over 100 matches
#
#  29%|██▊       | 286/1000 [21:55<47:56,  4.03s/it]INFO:root:
# Best Agent of 287° generation won 71.0 over 100 matches
#
#  29%|██▊       | 287/1000 [22:00<50:04,  4.21s/it]INFO:root:
# Best Agent of 288° generation won 71.0 over 100 matches
#
#  29%|██▉       | 288/1000 [22:05<51:36,  4.35s/it]INFO:root:
# Best Agent of 289° generation won 71.0 over 100 matches
#
#  29%|██▉       | 289/1000 [22:09<50:08,  4.23s/it]INFO:root:
# Best Agent of 290° generation won 71.0 over 100 matches
#
#  29%|██▉       | 290/1000 [22:13<50:12,  4.24s/it]INFO:root:
# Best Agent of 291° generation won 71.0 over 100 matches
#
#  29%|██▉       | 291/1000 [22:21<1:03:29,  5.37s/it]INFO:root:
# Best Agent of 292° generation won 71.0 over 100 matches
#
#  29%|██▉       | 292/1000 [22:25<59:34,  5.05s/it]  INFO:root:
# Best Agent of 293° generation won 71.0 over 100 matches
#
#  29%|██▉       | 293/1000 [22:29<55:02,  4.67s/it]INFO:root:
# Best Agent of 294° generation won 71.0 over 100 matches
#
#  29%|██▉       | 294/1000 [22:33<53:33,  4.55s/it]INFO:root:
# Best Agent of 295° generation won 71.0 over 100 matches
#
#  30%|██▉       | 295/1000 [22:37<52:08,  4.44s/it]INFO:root:
# Best Agent of 296° generation won 71.0 over 100 matches
#
#  30%|██▉       | 296/1000 [22:43<55:38,  4.74s/it]INFO:root:
# Best Agent of 297° generation won 71.0 over 100 matches
#
#  30%|██▉       | 297/1000 [22:51<1:07:32,  5.76s/it]INFO:root:
# Best Agent of 298° generation won 71.0 over 100 matches
#
#  30%|██▉       | 298/1000 [22:55<1:01:54,  5.29s/it]INFO:root:
# Best Agent of 299° generation won 71.0 over 100 matches
#
#  30%|██▉       | 299/1000 [22:59<57:32,  4.93s/it]  INFO:root:
# Best Agent of 300° generation won 71.0 over 100 matches
#
#  30%|███       | 300/1000 [23:03<54:39,  4.68s/it]INFO:root:
# Best Agent of 301° generation won 71.0 over 100 matches
#
#  30%|███       | 301/1000 [23:08<52:28,  4.50s/it]INFO:root:
# Best Agent of 302° generation won 71.0 over 100 matches
#
#  30%|███       | 302/1000 [23:12<52:43,  4.53s/it]INFO:root:
# Best Agent of 303° generation won 71.0 over 100 matches
#
#  30%|███       | 303/1000 [23:18<56:28,  4.86s/it]INFO:root:
# Best Agent of 304° generation won 71.0 over 100 matches
#
#  30%|███       | 304/1000 [23:23<56:07,  4.84s/it]INFO:root:
# Best Agent of 305° generation won 71.0 over 100 matches
#
#  30%|███       | 305/1000 [23:27<55:20,  4.78s/it]INFO:root:
# Best Agent of 306° generation won 71.0 over 100 matches
#
#  31%|███       | 306/1000 [23:32<56:55,  4.92s/it]INFO:root:
# Best Agent of 307° generation won 71.0 over 100 matches
#
#  31%|███       | 307/1000 [23:37<56:35,  4.90s/it]INFO:root:
# Best Agent of 308° generation won 71.0 over 100 matches
#
#  31%|███       | 308/1000 [23:41<53:22,  4.63s/it]INFO:root:
# Best Agent of 309° generation won 71.0 over 100 matches
#
#  31%|███       | 309/1000 [23:46<52:11,  4.53s/it]INFO:root:
# Best Agent of 310° generation won 71.0 over 100 matches
#
#  31%|███       | 310/1000 [23:51<54:48,  4.77s/it]INFO:root:
# Best Agent of 311° generation won 71.0 over 100 matches
#
#  31%|███       | 311/1000 [23:55<52:13,  4.55s/it]INFO:root:
# Best Agent of 312° generation won 71.0 over 100 matches
#
#  31%|███       | 312/1000 [23:59<50:04,  4.37s/it]INFO:root:
# Best Agent of 313° generation won 71.0 over 100 matches
#
#  31%|███▏      | 313/1000 [24:03<48:54,  4.27s/it]INFO:root:
# Best Agent of 314° generation won 71.0 over 100 matches
#
#  31%|███▏      | 314/1000 [24:07<47:59,  4.20s/it]INFO:root:
# Best Agent of 315° generation won 71.0 over 100 matches
#
#  32%|███▏      | 315/1000 [24:11<47:14,  4.14s/it]INFO:root:
# Best Agent of 316° generation won 71.0 over 100 matches
#
#  32%|███▏      | 316/1000 [24:15<47:01,  4.13s/it]INFO:root:
# Best Agent of 317° generation won 71.0 over 100 matches
#
#  32%|███▏      | 317/1000 [24:19<46:48,  4.11s/it]INFO:root:
# Best Agent of 318° generation won 71.0 over 100 matches
#
#  32%|███▏      | 318/1000 [24:23<46:14,  4.07s/it]INFO:root:
# Best Agent of 319° generation won 71.0 over 100 matches
#
#  32%|███▏      | 319/1000 [24:27<45:50,  4.04s/it]INFO:root:
# Best Agent of 320° generation won 71.0 over 100 matches
#
#  32%|███▏      | 320/1000 [24:31<45:28,  4.01s/it]INFO:root:
# Best Agent of 321° generation won 71.0 over 100 matches
#
#  32%|███▏      | 321/1000 [24:35<46:54,  4.14s/it]INFO:root:
# Best Agent of 322° generation won 71.0 over 100 matches
#
#  32%|███▏      | 322/1000 [24:40<47:07,  4.17s/it]INFO:root:
# Best Agent of 323° generation won 71.0 over 100 matches
#
#  32%|███▏      | 323/1000 [24:44<47:18,  4.19s/it]INFO:root:
# Best Agent of 324° generation won 71.0 over 100 matches
#
#  32%|███▏      | 324/1000 [24:49<49:00,  4.35s/it]INFO:root:
# Best Agent of 325° generation won 71.0 over 100 matches
#
#  32%|███▎      | 325/1000 [24:53<48:23,  4.30s/it]INFO:root:
# Best Agent of 326° generation won 71.0 over 100 matches
#
#  33%|███▎      | 326/1000 [24:57<47:46,  4.25s/it]INFO:root:
# Best Agent of 327° generation won 71.0 over 100 matches
#
#  33%|███▎      | 327/1000 [25:01<47:33,  4.24s/it]INFO:root:
# Best Agent of 328° generation won 71.0 over 100 matches
#
#  33%|███▎      | 328/1000 [25:05<47:28,  4.24s/it]INFO:root:
# Best Agent of 329° generation won 71.0 over 100 matches
#
#  33%|███▎      | 329/1000 [25:10<47:37,  4.26s/it]INFO:root:
# Best Agent of 330° generation won 71.0 over 100 matches
#
#  33%|███▎      | 330/1000 [25:14<47:06,  4.22s/it]INFO:root:
# Best Agent of 331° generation won 71.0 over 100 matches
#
#  33%|███▎      | 331/1000 [25:18<46:37,  4.18s/it]INFO:root:
# Best Agent of 332° generation won 71.0 over 100 matches
#
#  33%|███▎      | 332/1000 [25:22<46:27,  4.17s/it]INFO:root:
# Best Agent of 333° generation won 71.0 over 100 matches
#
#  33%|███▎      | 333/1000 [25:26<46:14,  4.16s/it]INFO:root:
# Best Agent of 334° generation won 71.0 over 100 matches
#
#  33%|███▎      | 334/1000 [25:30<45:39,  4.11s/it]INFO:root:
# Best Agent of 335° generation won 71.0 over 100 matches
#
#  34%|███▎      | 335/1000 [25:34<45:21,  4.09s/it]INFO:root:
# Best Agent of 336° generation won 71.0 over 100 matches
#
#  34%|███▎      | 336/1000 [25:38<44:57,  4.06s/it]INFO:root:
# Best Agent of 337° generation won 71.0 over 100 matches
#
#  34%|███▎      | 337/1000 [25:42<44:53,  4.06s/it]INFO:root:
# Best Agent of 338° generation won 71.0 over 100 matches
#
#  34%|███▍      | 338/1000 [25:46<44:46,  4.06s/it]INFO:root:
# Best Agent of 339° generation won 71.0 over 100 matches
#
#  34%|███▍      | 339/1000 [25:51<45:01,  4.09s/it]INFO:root:
# Best Agent of 340° generation won 71.0 over 100 matches
#
#  34%|███▍      | 340/1000 [25:55<45:05,  4.10s/it]INFO:root:
# Best Agent of 341° generation won 71.0 over 100 matches
#
#  34%|███▍      | 341/1000 [25:59<44:41,  4.07s/it]INFO:root:
# Best Agent of 342° generation won 71.0 over 100 matches
#
#  34%|███▍      | 342/1000 [26:03<44:27,  4.05s/it]INFO:root:
# Best Agent of 343° generation won 71.0 over 100 matches
#
#  34%|███▍      | 343/1000 [26:07<44:54,  4.10s/it]INFO:root:
# Best Agent of 344° generation won 71.0 over 100 matches
#
#  34%|███▍      | 344/1000 [26:11<44:22,  4.06s/it]INFO:root:
# Best Agent of 345° generation won 71.0 over 100 matches
#
#  34%|███▍      | 345/1000 [26:15<44:04,  4.04s/it]INFO:root:
# Best Agent of 346° generation won 71.0 over 100 matches
#
#  35%|███▍      | 346/1000 [26:19<43:48,  4.02s/it]INFO:root:
# Best Agent of 347° generation won 71.0 over 100 matches
#
#  35%|███▍      | 347/1000 [26:23<43:24,  3.99s/it]INFO:root:
# Best Agent of 348° generation won 71.0 over 100 matches
#
#  35%|███▍      | 348/1000 [26:27<43:23,  3.99s/it]INFO:root:
# Best Agent of 349° generation won 71.0 over 100 matches
#
#  35%|███▍      | 349/1000 [26:31<43:37,  4.02s/it]INFO:root:
# Best Agent of 350° generation won 71.0 over 100 matches
#
#  35%|███▌      | 350/1000 [26:36<45:49,  4.23s/it]INFO:root:
# Best Agent of 351° generation won 71.0 over 100 matches
#
#  35%|███▌      | 351/1000 [26:40<46:15,  4.28s/it]INFO:root:
# Best Agent of 352° generation won 71.0 over 100 matches
#
#  35%|███▌      | 352/1000 [26:45<47:23,  4.39s/it]INFO:root:
# Best Agent of 353° generation won 71.0 over 100 matches
#
#  35%|███▌      | 353/1000 [26:49<46:39,  4.33s/it]INFO:root:
# Best Agent of 354° generation won 71.0 over 100 matches
#
#  35%|███▌      | 354/1000 [26:53<46:27,  4.32s/it]INFO:root:
# Best Agent of 355° generation won 71.0 over 100 matches
#
#  36%|███▌      | 355/1000 [26:58<47:29,  4.42s/it]INFO:root:
# Best Agent of 356° generation won 71.0 over 100 matches
#
#  36%|███▌      | 356/1000 [27:02<47:35,  4.43s/it]INFO:root:
# Best Agent of 357° generation won 71.0 over 100 matches
#
#  36%|███▌      | 357/1000 [27:06<46:27,  4.34s/it]INFO:root:
# Best Agent of 358° generation won 71.0 over 100 matches
#
#  36%|███▌      | 358/1000 [27:10<45:34,  4.26s/it]INFO:root:
# Best Agent of 359° generation won 71.0 over 100 matches
#
#  36%|███▌      | 359/1000 [27:15<45:17,  4.24s/it]INFO:root:
# Best Agent of 360° generation won 71.0 over 100 matches
#
#  36%|███▌      | 360/1000 [27:19<45:01,  4.22s/it]INFO:root:
# Best Agent of 361° generation won 71.0 over 100 matches
#
#  36%|███▌      | 361/1000 [27:23<44:34,  4.19s/it]INFO:root:
# Best Agent of 362° generation won 71.0 over 100 matches
#
#  36%|███▌      | 362/1000 [27:27<44:10,  4.15s/it]INFO:root:
# Best Agent of 363° generation won 71.0 over 100 matches
#
#  36%|███▋      | 363/1000 [27:31<43:55,  4.14s/it]INFO:root:
# Best Agent of 364° generation won 71.0 over 100 matches
#
#  36%|███▋      | 364/1000 [27:35<44:03,  4.16s/it]INFO:root:
# Best Agent of 365° generation won 71.0 over 100 matches
#
#  36%|███▋      | 365/1000 [27:39<43:47,  4.14s/it]INFO:root:
# Best Agent of 366° generation won 71.0 over 100 matches
#
#  37%|███▋      | 366/1000 [27:43<43:14,  4.09s/it]INFO:root:
# Best Agent of 367° generation won 71.0 over 100 matches
#
#  37%|███▋      | 367/1000 [27:48<45:24,  4.30s/it]INFO:root:
# Best Agent of 368° generation won 71.0 over 100 matches
#
#  37%|███▋      | 368/1000 [27:53<47:36,  4.52s/it]INFO:root:
# Best Agent of 369° generation won 71.0 over 100 matches
#
#  37%|███▋      | 369/1000 [27:57<46:06,  4.38s/it]INFO:root:
# Best Agent of 370° generation won 71.0 over 100 matches
#
#  37%|███▋      | 370/1000 [28:01<45:36,  4.34s/it]INFO:root:
# Best Agent of 371° generation won 71.0 over 100 matches
#
#  37%|███▋      | 371/1000 [28:05<44:31,  4.25s/it]INFO:root:
# Best Agent of 372° generation won 71.0 over 100 matches
#
#  37%|███▋      | 372/1000 [28:09<43:39,  4.17s/it]INFO:root:
# Best Agent of 373° generation won 71.0 over 100 matches
#
#  37%|███▋      | 373/1000 [28:13<43:03,  4.12s/it]INFO:root:
# Best Agent of 374° generation won 71.0 over 100 matches
#
#  37%|███▋      | 374/1000 [28:18<43:39,  4.18s/it]INFO:root:
# Best Agent of 375° generation won 71.0 over 100 matches
#
#  38%|███▊      | 375/1000 [28:22<43:16,  4.15s/it]INFO:root:
# Best Agent of 376° generation won 71.0 over 100 matches
#
#  38%|███▊      | 376/1000 [28:26<43:09,  4.15s/it]INFO:root:
# Best Agent of 377° generation won 71.0 over 100 matches
#
#  38%|███▊      | 377/1000 [28:31<44:07,  4.25s/it]INFO:root:
# Best Agent of 378° generation won 71.0 over 100 matches
#
#  38%|███▊      | 378/1000 [28:35<43:34,  4.20s/it]INFO:root:
# Best Agent of 379° generation won 71.0 over 100 matches
#
#  38%|███▊      | 379/1000 [28:39<43:07,  4.17s/it]INFO:root:
# Best Agent of 380° generation won 71.0 over 100 matches
#
#  38%|███▊      | 380/1000 [28:43<42:28,  4.11s/it]INFO:root:
# Best Agent of 381° generation won 71.0 over 100 matches
#
#  38%|███▊      | 381/1000 [28:47<42:01,  4.07s/it]INFO:root:
# Best Agent of 382° generation won 71.0 over 100 matches
#
#  38%|███▊      | 382/1000 [28:51<42:14,  4.10s/it]INFO:root:
# Best Agent of 383° generation won 71.0 over 100 matches
#
#  38%|███▊      | 383/1000 [28:55<42:01,  4.09s/it]INFO:root:
# Best Agent of 384° generation won 71.0 over 100 matches
#
#  38%|███▊      | 384/1000 [28:59<41:53,  4.08s/it]INFO:root:
# Best Agent of 385° generation won 71.0 over 100 matches
#
#  38%|███▊      | 385/1000 [29:03<41:18,  4.03s/it]INFO:root:
# Best Agent of 386° generation won 71.0 over 100 matches
#
#  39%|███▊      | 386/1000 [29:07<40:48,  3.99s/it]INFO:root:
# Best Agent of 387° generation won 71.0 over 100 matches
#
#  39%|███▊      | 387/1000 [29:11<40:59,  4.01s/it]INFO:root:
# Best Agent of 388° generation won 71.0 over 100 matches
#
#  39%|███▉      | 388/1000 [29:15<41:07,  4.03s/it]INFO:root:
# Best Agent of 389° generation won 71.0 over 100 matches
#
#  39%|███▉      | 389/1000 [29:19<41:03,  4.03s/it]INFO:root:
# Best Agent of 390° generation won 71.0 over 100 matches
#
#  39%|███▉      | 390/1000 [29:23<40:57,  4.03s/it]INFO:root:
# Best Agent of 391° generation won 71.0 over 100 matches
#
#  39%|███▉      | 391/1000 [29:27<40:53,  4.03s/it]INFO:root:
# Best Agent of 392° generation won 71.0 over 100 matches
#
#  39%|███▉      | 392/1000 [29:31<40:59,  4.04s/it]INFO:root:
# Best Agent of 393° generation won 71.0 over 100 matches
#
#  39%|███▉      | 393/1000 [29:35<40:19,  3.99s/it]INFO:root:
# Best Agent of 394° generation won 71.0 over 100 matches
#
#  39%|███▉      | 394/1000 [29:39<40:32,  4.01s/it]INFO:root:
# Best Agent of 395° generation won 71.0 over 100 matches
#
#  40%|███▉      | 395/1000 [29:43<40:20,  4.00s/it]INFO:root:
# Best Agent of 396° generation won 71.0 over 100 matches
#
#  40%|███▉      | 396/1000 [29:47<40:04,  3.98s/it]INFO:root:
# Best Agent of 397° generation won 71.0 over 100 matches
#
#  40%|███▉      | 397/1000 [29:51<40:39,  4.05s/it]INFO:root:
# Best Agent of 398° generation won 71.0 over 100 matches
#
#  40%|███▉      | 398/1000 [29:55<40:03,  3.99s/it]INFO:root:
# Best Agent of 399° generation won 71.0 over 100 matches
#
#  40%|███▉      | 399/1000 [29:59<40:08,  4.01s/it]INFO:root:
# Best Agent of 400° generation won 71.0 over 100 matches
#
#  40%|████      | 400/1000 [30:03<39:43,  3.97s/it]INFO:root:
# Best Agent of 401° generation won 71.0 over 100 matches
#
#  40%|████      | 401/1000 [30:07<39:17,  3.93s/it]INFO:root:
# Best Agent of 402° generation won 71.0 over 100 matches
#
#  40%|████      | 402/1000 [30:11<39:45,  3.99s/it]INFO:root:
# Best Agent of 403° generation won 71.0 over 100 matches
#
#  40%|████      | 403/1000 [30:15<39:13,  3.94s/it]INFO:root:
# Best Agent of 404° generation won 71.0 over 100 matches
#
#  40%|████      | 404/1000 [30:19<39:03,  3.93s/it]INFO:root:
# Best Agent of 405° generation won 71.0 over 100 matches
#
#  40%|████      | 405/1000 [30:22<38:50,  3.92s/it]INFO:root:
# ...
#
#  88%|████████▊ | 881/1000 [1:03:01<07:24,  3.74s/it]INFO:root:
# Best Agent of 882° generation won 71.0 over 100 matches
#
#  88%|████████▊ | 882/1000 [1:03:04<07:13,  3.67s/it]INFO:root:
# Best Agent of 883° generation won 71.0 over 100 matches
#
#  88%|████████▊ | 883/1000 [1:03:08<07:00,  3.59s/it]INFO:root:
# Best Agent of 884° generation won 71.0 over 100 matches
#
#  88%|████████▊ | 884/1000 [1:03:11<06:51,  3.55s/it]INFO:root:
# Best Agent of 885° generation won 71.0 over 100 matches
#
#  88%|████████▊ | 885/1000 [1:03:14<06:38,  3.47s/it]INFO:root:
# Best Agent of 886° generation won 71.0 over 100 matches
#
#  89%|████████▊ | 886/1000 [1:03:18<06:27,  3.40s/it]INFO:root:
# Best Agent of 887° generation won 71.0 over 100 matches
#
#  89%|████████▊ | 887/1000 [1:03:21<06:36,  3.51s/it]INFO:root:
# Best Agent of 888° generation won 71.0 over 100 matches
#
#  89%|████████▉ | 888/1000 [1:03:26<06:56,  3.72s/it]INFO:root:
# Best Agent of 889° generation won 71.0 over 100 matches
#
#  89%|████████▉ | 889/1000 [1:03:29<06:45,  3.66s/it]INFO:root:
# Best Agent of 890° generation won 71.0 over 100 matches
#
#  89%|████████▉ | 890/1000 [1:03:33<06:34,  3.59s/it]INFO:root:
# Best Agent of 891° generation won 71.0 over 100 matches
#
#  89%|████████▉ | 891/1000 [1:03:36<06:22,  3.51s/it]INFO:root:
# Best Agent of 892° generation won 71.0 over 100 matches
#
#  89%|████████▉ | 892/1000 [1:03:39<06:16,  3.49s/it]INFO:root:
# Best Agent of 893° generation won 71.0 over 100 matches
#
#  89%|████████▉ | 893/1000 [1:03:43<06:21,  3.57s/it]INFO:root:
# Best Agent of 894° generation won 71.0 over 100 matches
#
#  89%|████████▉ | 894/1000 [1:03:48<06:57,  3.94s/it]INFO:root:
# Best Agent of 895° generation won 71.0 over 100 matches
#
#  90%|████████▉ | 895/1000 [1:03:52<06:44,  3.85s/it]INFO:root:
# Best Agent of 896° generation won 71.0 over 100 matches
#
#  90%|████████▉ | 896/1000 [1:03:55<06:31,  3.76s/it]INFO:root:
# Best Agent of 897° generation won 71.0 over 100 matches
#
#  90%|████████▉ | 897/1000 [1:03:59<06:29,  3.78s/it]INFO:root:
# Best Agent of 898° generation won 71.0 over 100 matches
#
#  90%|████████▉ | 898/1000 [1:04:03<06:35,  3.87s/it]INFO:root:
# Best Agent of 899° generation won 71.0 over 100 matches
#
#  90%|████████▉ | 899/1000 [1:04:07<06:21,  3.78s/it]INFO:root:
# Best Agent of 900° generation won 71.0 over 100 matches
#
#  90%|█████████ | 900/1000 [1:04:10<06:11,  3.71s/it]INFO:root:
# Best Agent of 901° generation won 71.0 over 100 matches
#
#  90%|█████████ | 901/1000 [1:04:14<06:08,  3.72s/it]INFO:root:
# Best Agent of 902° generation won 71.0 over 100 matches
#
#  90%|█████████ | 902/1000 [1:04:18<06:02,  3.70s/it]INFO:root:
# Best Agent of 903° generation won 71.0 over 100 matches
#
#  90%|█████████ | 903/1000 [1:04:21<05:49,  3.60s/it]INFO:root:
# Best Agent of 904° generation won 71.0 over 100 matches
#
#  90%|█████████ | 904/1000 [1:04:24<05:38,  3.53s/it]INFO:root:
# Best Agent of 905° generation won 71.0 over 100 matches
#
#  90%|█████████ | 905/1000 [1:04:28<05:33,  3.51s/it]INFO:root:
# Best Agent of 906° generation won 71.0 over 100 matches
#
#  91%|█████████ | 906/1000 [1:04:31<05:23,  3.45s/it]INFO:root:
# Best Agent of 907° generation won 71.0 over 100 matches
#
#  91%|█████████ | 907/1000 [1:04:34<05:15,  3.39s/it]INFO:root:
# Best Agent of 908° generation won 71.0 over 100 matches
#
#  91%|█████████ | 908/1000 [1:04:38<05:25,  3.53s/it]INFO:root:
# Best Agent of 909° generation won 71.0 over 100 matches
#
#  91%|█████████ | 909/1000 [1:04:42<05:22,  3.55s/it]INFO:root:
# Best Agent of 910° generation won 71.0 over 100 matches
#
#  91%|█████████ | 910/1000 [1:04:45<05:24,  3.61s/it]INFO:root:
# Best Agent of 911° generation won 71.0 over 100 matches
#
#  91%|█████████ | 911/1000 [1:04:49<05:21,  3.62s/it]INFO:root:
# Best Agent of 912° generation won 71.0 over 100 matches
#
#  91%|█████████ | 912/1000 [1:04:53<05:20,  3.64s/it]INFO:root:
# Best Agent of 913° generation won 71.0 over 100 matches
#
#  91%|█████████▏| 913/1000 [1:04:57<05:19,  3.67s/it]INFO:root:
# Best Agent of 914° generation won 71.0 over 100 matches
#
#  91%|█████████▏| 914/1000 [1:05:00<05:12,  3.64s/it]INFO:root:
# Best Agent of 915° generation won 71.0 over 100 matches
#
#  92%|█████████▏| 915/1000 [1:05:04<05:07,  3.61s/it]INFO:root:
# Best Agent of 916° generation won 71.0 over 100 matches
#
#  92%|█████████▏| 916/1000 [1:05:07<04:57,  3.54s/it]INFO:root:
# Best Agent of 917° generation won 71.0 over 100 matches
#
#  92%|█████████▏| 917/1000 [1:05:11<04:52,  3.53s/it]INFO:root:
# Best Agent of 918° generation won 71.0 over 100 matches
#
#  92%|█████████▏| 918/1000 [1:05:14<04:50,  3.54s/it]INFO:root:
# Best Agent of 919° generation won 71.0 over 100 matches
#
#  92%|█████████▏| 919/1000 [1:05:18<04:43,  3.50s/it]INFO:root:
# Best Agent of 920° generation won 71.0 over 100 matches
#
#  92%|█████████▏| 920/1000 [1:05:21<04:39,  3.49s/it]INFO:root:
# Best Agent of 921° generation won 71.0 over 100 matches
#
#  92%|█████████▏| 921/1000 [1:05:24<04:31,  3.44s/it]INFO:root:
# Best Agent of 922° generation won 71.0 over 100 matches
#
#  92%|█████████▏| 922/1000 [1:05:28<04:32,  3.49s/it]INFO:root:
# Best Agent of 923° generation won 71.0 over 100 matches
#
#  92%|█████████▏| 923/1000 [1:05:31<04:27,  3.48s/it]INFO:root:
# Best Agent of 924° generation won 71.0 over 100 matches
#
#  92%|█████████▏| 924/1000 [1:05:35<04:23,  3.47s/it]INFO:root:
# Best Agent of 925° generation won 71.0 over 100 matches
#
#  92%|█████████▎| 925/1000 [1:05:38<04:17,  3.43s/it]INFO:root:
# Best Agent of 926° generation won 71.0 over 100 matches
#
#  93%|█████████▎| 926/1000 [1:05:42<04:16,  3.46s/it]INFO:root:
# Best Agent of 927° generation won 71.0 over 100 matches
#
#  93%|█████████▎| 927/1000 [1:05:45<04:12,  3.46s/it]INFO:root:
# Best Agent of 928° generation won 71.0 over 100 matches
#
#  93%|█████████▎| 928/1000 [1:05:49<04:09,  3.46s/it]INFO:root:
# Best Agent of 929° generation won 71.0 over 100 matches
#
#  93%|█████████▎| 929/1000 [1:05:52<04:01,  3.40s/it]INFO:root:
# Best Agent of 930° generation won 71.0 over 100 matches
#
#  93%|█████████▎| 930/1000 [1:05:55<03:57,  3.39s/it]INFO:root:
# Best Agent of 931° generation won 71.0 over 100 matches
#
#  93%|█████████▎| 931/1000 [1:05:58<03:50,  3.34s/it]INFO:root:
# Best Agent of 932° generation won 71.0 over 100 matches
#
#  93%|█████████▎| 932/1000 [1:06:02<03:49,  3.37s/it]INFO:root:
# Best Agent of 933° generation won 71.0 over 100 matches
#
#  93%|█████████▎| 933/1000 [1:06:05<03:44,  3.36s/it]INFO:root:
# Best Agent of 934° generation won 71.0 over 100 matches
#
#  93%|█████████▎| 934/1000 [1:06:09<03:43,  3.39s/it]INFO:root:
# Best Agent of 935° generation won 71.0 over 100 matches
#
#  94%|█████████▎| 935/1000 [1:06:13<03:48,  3.51s/it]INFO:root:
# Best Agent of 936° generation won 71.0 over 100 matches
#
#  94%|█████████▎| 936/1000 [1:06:16<03:50,  3.60s/it]INFO:root:
# Best Agent of 937° generation won 71.0 over 100 matches
#
#  94%|█████████▎| 937/1000 [1:06:20<03:46,  3.60s/it]INFO:root:
# Best Agent of 938° generation won 71.0 over 100 matches
#
#  94%|█████████▍| 938/1000 [1:06:24<03:44,  3.62s/it]INFO:root:
# Best Agent of 939° generation won 71.0 over 100 matches
#
#  94%|█████████▍| 939/1000 [1:06:27<03:38,  3.58s/it]INFO:root:
# Best Agent of 940° generation won 71.0 over 100 matches
#
#  94%|█████████▍| 940/1000 [1:06:31<03:35,  3.60s/it]INFO:root:
# Best Agent of 941° generation won 71.0 over 100 matches
#
#  94%|█████████▍| 941/1000 [1:06:34<03:33,  3.63s/it]INFO:root:
# Best Agent of 942° generation won 71.0 over 100 matches
#
#  94%|█████████▍| 942/1000 [1:06:38<03:29,  3.61s/it]INFO:root:
# Best Agent of 943° generation won 71.0 over 100 matches
#
#  94%|█████████▍| 943/1000 [1:06:43<03:43,  3.92s/it]INFO:root:
# Best Agent of 944° generation won 71.0 over 100 matches
#
#  94%|█████████▍| 944/1000 [1:06:47<03:44,  4.02s/it]INFO:root:
# Best Agent of 945° generation won 71.0 over 100 matches
#
#  94%|█████████▍| 945/1000 [1:06:51<03:41,  4.02s/it]INFO:root:
# Best Agent of 946° generation won 71.0 over 100 matches
#
#  95%|█████████▍| 946/1000 [1:06:55<03:31,  3.91s/it]INFO:root:
# Best Agent of 947° generation won 71.0 over 100 matches
#
#  95%|█████████▍| 947/1000 [1:06:58<03:27,  3.91s/it]INFO:root:
# Best Agent of 948° generation won 71.0 over 100 matches
#
#  95%|█████████▍| 948/1000 [1:07:02<03:16,  3.78s/it]INFO:root:
# Best Agent of 949° generation won 71.0 over 100 matches
#
#  95%|█████████▍| 949/1000 [1:07:06<03:22,  3.97s/it]INFO:root:
# Best Agent of 950° generation won 71.0 over 100 matches
#
#  95%|█████████▌| 950/1000 [1:07:10<03:17,  3.95s/it]INFO:root:
# Best Agent of 951° generation won 71.0 over 100 matches
#
#  95%|█████████▌| 951/1000 [1:07:14<03:06,  3.81s/it]INFO:root:
# Best Agent of 952° generation won 71.0 over 100 matches
#
#  95%|█████████▌| 952/1000 [1:07:17<02:56,  3.67s/it]INFO:root:
# Best Agent of 953° generation won 71.0 over 100 matches
#
#  95%|█████████▌| 953/1000 [1:07:21<02:51,  3.65s/it]INFO:root:
# Best Agent of 954° generation won 71.0 over 100 matches
#
#  95%|█████████▌| 954/1000 [1:07:24<02:46,  3.62s/it]INFO:root:
# Best Agent of 955° generation won 71.0 over 100 matches
#
#  96%|█████████▌| 955/1000 [1:07:28<02:46,  3.70s/it]INFO:root:
# Best Agent of 956° generation won 71.0 over 100 matches
#
#  96%|█████████▌| 956/1000 [1:07:32<02:44,  3.74s/it]INFO:root:
# Best Agent of 957° generation won 71.0 over 100 matches
#
#  96%|█████████▌| 957/1000 [1:07:36<02:44,  3.82s/it]INFO:root:
# Best Agent of 958° generation won 71.0 over 100 matches
#
#  96%|█████████▌| 958/1000 [1:07:40<02:41,  3.83s/it]INFO:root:
# Best Agent of 959° generation won 71.0 over 100 matches
#
#  96%|█████████▌| 959/1000 [1:07:44<02:35,  3.80s/it]INFO:root:
# Best Agent of 960° generation won 71.0 over 100 matches
#
#  96%|█████████▌| 960/1000 [1:07:47<02:29,  3.74s/it]INFO:root:
# Best Agent of 961° generation won 71.0 over 100 matches
#
#  96%|█████████▌| 961/1000 [1:07:51<02:27,  3.79s/it]INFO:root:
# Best Agent of 962° generation won 71.0 over 100 matches
#
#  96%|█████████▌| 962/1000 [1:07:55<02:20,  3.71s/it]INFO:root:
# Best Agent of 963° generation won 71.0 over 100 matches
#
#  96%|█████████▋| 963/1000 [1:07:58<02:14,  3.64s/it]INFO:root:
# Best Agent of 964° generation won 71.0 over 100 matches
#
#  96%|█████████▋| 964/1000 [1:08:02<02:16,  3.80s/it]INFO:root:
# Best Agent of 965° generation won 71.0 over 100 matches
#
#  96%|█████████▋| 965/1000 [1:08:06<02:16,  3.89s/it]INFO:root:
# Best Agent of 966° generation won 71.0 over 100 matches
#
#  97%|█████████▋| 966/1000 [1:08:10<02:10,  3.85s/it]INFO:root:
# Best Agent of 967° generation won 71.0 over 100 matches
#
#  97%|█████████▋| 967/1000 [1:08:14<02:05,  3.81s/it]INFO:root:
# Best Agent of 968° generation won 71.0 over 100 matches
#
#  97%|█████████▋| 968/1000 [1:08:18<02:02,  3.82s/it]INFO:root:
# Best Agent of 969° generation won 71.0 over 100 matches
#
#  97%|█████████▋| 969/1000 [1:08:21<01:57,  3.79s/it]INFO:root:
# Best Agent of 970° generation won 71.0 over 100 matches
#
#  97%|█████████▋| 970/1000 [1:08:25<01:55,  3.85s/it]INFO:root:
# Best Agent of 971° generation won 71.0 over 100 matches
#
#  97%|█████████▋| 971/1000 [1:08:29<01:50,  3.80s/it]INFO:root:
# Best Agent of 972° generation won 71.0 over 100 matches
#
#  97%|█████████▋| 972/1000 [1:08:33<01:43,  3.70s/it]INFO:root:
# Best Agent of 973° generation won 71.0 over 100 matches
#
#  97%|█████████▋| 973/1000 [1:08:36<01:37,  3.60s/it]INFO:root:
# Best Agent of 974° generation won 71.0 over 100 matches
#
#  97%|█████████▋| 974/1000 [1:08:39<01:32,  3.57s/it]INFO:root:
# Best Agent of 975° generation won 71.0 over 100 matches
#
#  98%|█████████▊| 975/1000 [1:08:43<01:27,  3.51s/it]INFO:root:
# Best Agent of 976° generation won 71.0 over 100 matches
#
#  98%|█████████▊| 976/1000 [1:08:46<01:22,  3.43s/it]INFO:root:
# Best Agent of 977° generation won 71.0 over 100 matches
#
#  98%|█████████▊| 977/1000 [1:08:51<01:27,  3.79s/it]INFO:root:
# Best Agent of 978° generation won 71.0 over 100 matches
#
#  98%|█████████▊| 978/1000 [1:08:54<01:22,  3.75s/it]INFO:root:
# Best Agent of 979° generation won 71.0 over 100 matches
#
#  98%|█████████▊| 979/1000 [1:08:58<01:16,  3.64s/it]INFO:root:
# Best Agent of 980° generation won 71.0 over 100 matches
#
#  98%|█████████▊| 980/1000 [1:09:01<01:10,  3.53s/it]INFO:root:
# Best Agent of 981° generation won 71.0 over 100 matches
#
#  98%|█████████▊| 981/1000 [1:09:04<01:05,  3.45s/it]INFO:root:
# Best Agent of 982° generation won 71.0 over 100 matches
#
#  98%|█████████▊| 982/1000 [1:09:08<01:01,  3.43s/it]INFO:root:
# Best Agent of 983° generation won 71.0 over 100 matches
#
#  98%|█████████▊| 983/1000 [1:09:11<00:57,  3.40s/it]INFO:root:
# Best Agent of 984° generation won 71.0 over 100 matches
#
#  98%|█████████▊| 984/1000 [1:09:14<00:54,  3.38s/it]INFO:root:
# Best Agent of 985° generation won 71.0 over 100 matches
#
#  98%|█████████▊| 985/1000 [1:09:18<00:50,  3.38s/it]INFO:root:
# Best Agent of 986° generation won 71.0 over 100 matches
#
#  99%|█████████▊| 986/1000 [1:09:21<00:47,  3.37s/it]INFO:root:
# Best Agent of 987° generation won 71.0 over 100 matches
#
#  99%|█████████▊| 987/1000 [1:09:25<00:44,  3.43s/it]INFO:root:
# Best Agent of 988° generation won 71.0 over 100 matches
#
#  99%|█████████▉| 988/1000 [1:09:28<00:41,  3.49s/it]INFO:root:
# Best Agent of 989° generation won 71.0 over 100 matches
#
#  99%|█████████▉| 989/1000 [1:09:32<00:39,  3.55s/it]INFO:root:
# Best Agent of 990° generation won 71.0 over 100 matches
#
#  99%|█████████▉| 990/1000 [1:09:35<00:35,  3.56s/it]INFO:root:
# Best Agent of 991° generation won 71.0 over 100 matches
#
#  99%|█████████▉| 991/1000 [1:09:39<00:31,  3.48s/it]INFO:root:
# Best Agent of 992° generation won 71.0 over 100 matches
#
#  99%|█████████▉| 992/1000 [1:09:43<00:28,  3.59s/it]INFO:root:
# Best Agent of 993° generation won 71.0 over 100 matches
#
#  99%|█████████▉| 993/1000 [1:09:47<00:25,  3.68s/it]INFO:root:
# Best Agent of 994° generation won 71.0 over 100 matches
#
#  99%|█████████▉| 994/1000 [1:09:50<00:22,  3.77s/it]INFO:root:
# Best Agent of 995° generation won 71.0 over 100 matches
#
# 100%|█████████▉| 995/1000 [1:09:54<00:18,  3.69s/it]INFO:root:
# Best Agent of 996° generation won 71.0 over 100 matches
#
# 100%|█████████▉| 996/1000 [1:09:58<00:14,  3.73s/it]INFO:root:
# Best Agent of 997° generation won 71.0 over 100 matches
#
# 100%|█████████▉| 997/1000 [1:10:01<00:11,  3.67s/it]INFO:root:
# Best Agent of 998° generation won 71.0 over 100 matches
#
# 100%|█████████▉| 998/1000 [1:10:05<00:07,  3.58s/it]INFO:root:
# Best Agent of 999° generation won 71.0 over 100 matches
#
# 100%|█████████▉| 999/1000 [1:10:08<00:03,  3.55s/it]INFO:root:
# Best Agent of 1000° generation won 71.0 over 100 matches
#
# 100%|██████████| 1000/1000 [1:10:12<00:00,  4.21s/it]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Lorenzo Ugoccioni\Documents\PoliTo\LM - II anno\Computational Intelligence\Coding\Laboratory\Lab2\lab2-nim.ipynb Cella 24 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/Lorenzo%20Ugoccioni/Documents/PoliTo/LM%20-%20II%20anno/Computational%20Intelligence/Coding/Laboratory/Lab2/lab2-nim.ipynb#X25sZmlsZQ%3D%3D?line=22'>23</a>     history.append(current_population[0].fitness)
#      <a href='vscode-notebook-cell:/c%3A/Users/Lorenzo%20Ugoccioni/Documents/PoliTo/LM%20-%20II%20anno/Computational%20Intelligence/Coding/Laboratory/Lab2/lab2-nim.ipynb#X25sZmlsZQ%3D%3D?line=24'>25</a> best_agent = copy(current_population[0].fitness)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Lorenzo%20Ugoccioni/Documents/PoliTo/LM%20-%20II%20anno/Computational%20Intelligence/Coding/Laboratory/Lab2/lab2-nim.ipynb#X25sZmlsZQ%3D%3D?line=25'>26</a> logging.info(f"\nBest solution: {best_agent.fitness}\nRows choice: {best_agent.genotype[0]}\nElement choice: {best_agent.genotype[1]}")
#      <a href='vscode-notebook-cell:/c%3A/Users/Lorenzo%20Ugoccioni/Documents/PoliTo/LM%20-%20II%20anno/Computational%20Intelligence/Coding/Laboratory/Lab2/lab2-nim.ipynb#X25sZmlsZQ%3D%3D?line=27'>28</a> history = np.array(history)
#      <a href='vscode-notebook-cell:/c%3A/Users/Lorenzo%20Ugoccioni/Documents/PoliTo/LM%20-%20II%20anno/Computational%20Intelligence/Coding/Laboratory/Lab2/lab2-nim.ipynb#X25sZmlsZQ%3D%3D?line=28'>29</a> generations = list(range(1, 50 + 1))
#
# AttributeError: 'float' object has no attribute 'fitness'

# %%
best_agent = current_population[0]

# %%
logging.getLogger().setLevel(logging.INFO)

strategy = (best_agent, optimal)
win = 0

for _ in range(100):
    nim = Nim(GAME_DIMENSION)
    # logging.info(f"init : {nim}")
    player = random.choice([0, 1])
    while nim:
        if player == 0:
            ply = player_move(players[0], nim)
            # logging.info(f"ply: player agent plays {ply}")
        if player == 1:
            ply = players[player](nim)
            # logging.info(f"ply: opponent plays {ply}")
        nim.nimming(ply)
        # logging.info(f"status: {nim}")
        player = 1 - player
    # logging.info(f"status: { 'Agent'if player==0 else 'Opponent'} won!")
    if player == 0 : win += 1

print("\nWin rate: ", win/100)
# Out:
# INFO:root:init : <1 3 5 7 9>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Lorenzo Ugoccioni\Documents\PoliTo\LM - II anno\Computational Intelligence\Coding\Laboratory\Lab2\lab2-nim.ipynb Cella 26 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/Lorenzo%20Ugoccioni/Documents/PoliTo/LM%20-%20II%20anno/Computational%20Intelligence/Coding/Laboratory/Lab2/lab2-nim.ipynb#X35sZmlsZQ%3D%3D?line=7'>8</a> player = 0
#       <a href='vscode-notebook-cell:/c%3A/Users/Lorenzo%20Ugoccioni/Documents/PoliTo/LM%20-%20II%20anno/Computational%20Intelligence/Coding/Laboratory/Lab2/lab2-nim.ipynb#X35sZmlsZQ%3D%3D?line=8'>9</a> while nim:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Lorenzo%20Ugoccioni/Documents/PoliTo/LM%20-%20II%20anno/Computational%20Intelligence/Coding/Laboratory/Lab2/lab2-nim.ipynb#X35sZmlsZQ%3D%3D?line=9'>10</a>     ply = strategy[player](nim)
#      <a href='vscode-notebook-cell:/c%3A/Users/Lorenzo%20Ugoccioni/Documents/PoliTo/LM%20-%20II%20anno/Computational%20Intelligence/Coding/Laboratory/Lab2/lab2-nim.ipynb#X35sZmlsZQ%3D%3D?line=10'>11</a>     logging.info(f"ply: player {player} plays {ply}")
#      <a href='vscode-notebook-cell:/c%3A/Users/Lorenzo%20Ugoccioni/Documents/PoliTo/LM%20-%20II%20anno/Computational%20Intelligence/Coding/Laboratory/Lab2/lab2-nim.ipynb#X35sZmlsZQ%3D%3D?line=11'>12</a>     nim.nimming(ply)
#
# TypeError: 'Individual' object is not callable
